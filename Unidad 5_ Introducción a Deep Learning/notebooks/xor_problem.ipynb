# %% [markdown]
# # Resolución del problema XOR con redes neuronales

# %% [markdown]
# #### Carga de bibliotecas y datos

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import tensorflow as tf
from mpl_toolkits.mplot3d import Axes3D

# %%
import warnings
warnings.simplefilter('ignore')
from sklearn.metrics import mean_squared_error

# %%
# %matplotlib inline
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}
from matplotlib import pyplot as plt
#plt.style.use(['seaborn-darkgrid'])
plt.rcParams['figure.figsize'] = (15, 7)
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 20

# %%
# Conjunto de datos XOR
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
Y = np.array([0, 1, 1, 0])

# Visualizar datos
plt.figure(figsize=(10,5))
plt.scatter(X[:, 0], X[:, 1], c=Y)
plt.xlabel("X1")
plt.ylabel("X2")
plt.title("Conjunto de Datos XOR")
plt.grid()
plt.show()

# %% [markdown]
# #### Regresión lineal

# %%
# se crea y entrena un modelo de regresión lineal
linear_model = LinearRegression()
linear_model.fit(X, Y)
print('Parámetros de la regresión lineal:', linear_model.coef_, linear_model.intercept_)

# Gráfico de Regresión Lineal
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Visualizar los datos
ax.scatter(X[:, 0], X[:, 1], Y, c='r', marker='o', label='Datos reales')

# Crear un plano de regresión
x_mesh, y_mesh = np.meshgrid(np.linspace(0, 1, 10), np.linspace(0, 1, 10))
z_mesh = linear_model.predict(np.c_[x_mesh.ravel(), y_mesh.ravel()])
z_mesh = z_mesh.reshape(x_mesh.shape)
ax.plot_surface(x_mesh, y_mesh, z_mesh, alpha=0.5, rstride=100, cstride=100, cmap='viridis', label='Plano de Regresión')

ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('output')
ax.set_title('Regresión lineal múltiple')
plt.show()
# Out:
# Parámetros de la regresión lineal: [ 0.00000000e+00 -2.22044605e-16] 0.5000000000000001

# %%
from sklearn.metrics import mean_squared_error

w1_range = np.linspace(linear_model.coef_[0] - 1, linear_model.coef_[0] + 1, 50)
w2_range = np.linspace(linear_model.coef_[1] - 1, linear_model.coef_[1] + 1, 50)
w1_mesh, w2_mesh = np.meshgrid(w1_range, w2_range)

# calculo el MSE para cada par de coeficientes
mse_values = np.zeros_like(w1_mesh)
for i in range(w1_mesh.shape[0]):
    for j in range(w1_mesh.shape[1]):
        coef_temp = np.array([w1_mesh[i, j], w2_mesh[i, j]])
        Y_pred_temp = X @ coef_temp + linear_model.intercept_
        # calculo MSE
        mse_values[i, j] = mean_squared_error(Y, Y_pred_temp)

# función de costo como curvas de nivel
plt.figure(figsize=(10, 6))
cp = plt.contourf(w1_mesh, w2_mesh, mse_values, 20, cmap='viridis')
plt.colorbar(cp)
plt.xlabel('Coeficiente W1')
plt.ylabel('Coeficiente W2')
plt.title('Función de Costo (MSE)')
plt.show()

# %%
fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(w1_mesh, w2_mesh, mse_values, cmap='viridis', alpha=0.7)
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)

min_w1 = linear_model.coef_[0]
min_w2 = linear_model.coef_[1]
min_mse = mean_squared_error(Y, linear_model.predict(X))
ax.scatter(min_w1, min_w2, min_mse, color='red', s=50, label='Mínimo (óptimo)')
ax.set_zlim(0, 2)

ax.legend()

ax.view_init(elev=0, azim=135)

#ax.set_xlabel('Coeficiente W1')
#ax.set_ylabel('Coeficiente W2')
ax.set_zlabel('MSE')
ax.set_title('Función de Costo (MSE) en función de W1 y W2')

plt.show()

print('Mínimo de la función de costo (MSE):', min_mse)
# Out:
# Mínimo de la función de costo (MSE): 0.25

# %%
linear_model.predict(X)

## las predicciones son siempre 0.5, un modelo lineal no alcanza a modelizar este problema
# Out:
# array([0.5, 0.5, 0.5, 0.5])

# %%
mse_linear_model=mean_squared_error(Y, linear_model.predict(X))
mse_linear_model
# Out:
# 0.25

# %% [markdown]
# ### Red Neuronal con numpy

# %% [markdown]
# Esta red neuronal contiene una capa oculta de dos neuronas y una sola output, con lo cual tiene 9 parámetros. Estos 9 parámetros son tres por neurona (ya que la capa anterior a cada neurona tiene 2 neuronas, es decir, 2 pesos y un bias). Con lo cual se inicializan tres vectores de parámetros:
#
# W1_1 = vector con parámetros de la neurona 1 de la capa oculta.
#
# W2_1 = vector con parámetros de la neurona 2 de la capa oculta.
#
# W1_2 = vector con parámetros de la neurona de salida

# %%
class NeuralNetwork():
    """
    Modelo de red neuronal simple con numpy
    """
    def __init__(self):
        ### inicialización de pesos de los tres vectores
        self.W1_1 = None
        self.W2_1 = None
        self.W1_2 = None
    
    def sigmoid(self, x):
        # Función sigmoidea para la función de activación
        g_x = 1 / (1 + np.exp(-x))
        return g_x
        
    def fit(self, X, y, lr=0.1, epochs=20000):
        
        # para medir la evolución del MSE a través de las iteraciones
        mse_epoch = []
        
        # se agrega una columna de unos
        X = np.append(X, np.ones(shape=(X.shape[0],1)), axis = 1) 
        
        n = X.shape[0] # number of samples
        m = X.shape[1] # number of features
        
        # inicialización random de los pesos
        W1_1 = np.random.random(size=(m, 1))
        W2_1 = np.random.random(size=(m,1))
        W1_2 = np.random.random(size=(3,1))
        
        # se itera sobre todas las epocas
        for j in range(epochs):

            # orden random de las muestras
            idx = np.random.permutation(X.shape[0])
            X = X[idx]
            y = y[idx]
            
            # funcion de perdida inicial
            mse=0

            # Iteramos en el dataset (SGD)
            for i in range(n):

                # Forward propagation, con esto se obtiene la ecuación para la salida
                z1 = X[i,:]@W1_1
                z1 = z1[0]
                a1 = self.sigmoid(z1)
                
                z2 = X[i,:]@W2_1
                z2 = z2[0]
                a2 = self.sigmoid(z2)
                
                x1_2 = np.array([a1,a2,1])
                z3 = x1_2@W1_2
                z3 = z3[0]
                a3 = self.sigmoid(z3)
                
                prediction = a3
                
                # se calcula el error
                error = np.power(y[i] - prediction,2)

                # acumulo el error en la función de pérdida
                mse = mse + error
                
                # se calcula el gradiente, ecuaciones back propagation, recordar que la derivada de la sigmoidea es sigm(1-sigm).
                grad_W1_2 = (-2/n) * (y[i] - prediction) * self.sigmoid(z3) * (1-self.sigmoid(z3)) * x1_2
                grad_W2_1 = (-2/n) * (y[i] - prediction) * self.sigmoid(z3) * (1-self.sigmoid(z3)) * W1_2[1] * \
                            self.sigmoid(z2) * (1-self.sigmoid(z2)) * X[i,:]
                grad_W1_1 = (-2/n) * (y[i] - prediction) * self.sigmoid(z3) * (1-self.sigmoid(z3)) * W1_2[0] * \
                            self.sigmoid(z1) * (1-self.sigmoid(z1)) * X[i,:]
                
                # actualizo pesos
                W1_2 = W1_2 - (lr * grad_W1_2[:,np.newaxis])
                W2_1 = W2_1 - (lr * grad_W2_1[:,np.newaxis])
                W1_1 = W1_1 - (lr * grad_W1_1[:,np.newaxis])
            
            # se calcula error para la época, se divide por n que es la cantidad de muestras
            mse_epoch.append(mse/n)
                        
         ### no imprimo el error por época porque llenaría la pantalla de mensajes pero lo imprimimos diez veces para ir trackeando la evolución
            if (j % (epochs/10)) == 0:
                print("Epoch ",j," MSE: ", mse/n)
        
        # guardamos los parametros
        self.W1_1 = W1_1
        self.W2_1 = W2_1
        self.W1_2 = W1_2
        
        # devolvemos el error de entrenamiento, por época, para poder graficarlo, es una medida muy útil
        return mse_epoch, W1_1, W2_1, W1_2
    
    def predict(self,X):
        
        # se agrega una columna de unos a X
        X=np.append(X, np.ones(shape=(X.shape[0],1)), axis = 1)
        n = X.shape[0]
        
        prediction = []
        
        # iteramos en el dataset que se esta prediciendo
        for i in range(n):
            # Forward propagation, acá no hay que hacer backward, no hay nada que optimizar, 
            # solo hay que buscar la ecuación de predicción con los parámetros ya entrenados
            z1 = X[i,:]@self.W1_1
            z1 = z1[0]
            a1 = self.sigmoid(z1)
            
            z2 = X[i,:]@self.W2_1
            z2 = z2[0]
            a2 = self.sigmoid(z2)
            
            x1_2 = np.array([a1,a2,1])
            z3 = x1_2@self.W1_2
            z3 = z3[0]
            a3 = self.sigmoid(z3)
            
            prediction.append(a3)

        return np.array(prediction)

# %%
### Entreno mi red neuronal
model = NeuralNetwork()
mse_epoch, W1_1, W2_1, W1_2 = model.fit(X,Y, lr=0.3, epochs=10000)

### en caso que vea que el error no mejora respecto de la regresión lineal, puedo cambiar el learning_rate o la cantidad de iteraciones para la convergencia.
# Out:
# Epoch  0  MSE:  0.34068678644832967
# Epoch  1000  MSE:  0.2311060998994304
# Epoch  2000  MSE:  0.1630860894990391
# Epoch  3000  MSE:  0.027717248735623763
# Epoch  4000  MSE:  0.008828995599115118
# Epoch  5000  MSE:  0.004893350377898718
# Epoch  6000  MSE:  0.0033140462141807324
# Epoch  7000  MSE:  0.0024817919628904316
# Epoch  8000  MSE:  0.001973361389966297
# Epoch  9000  MSE:  0.001632597336011091

# %%
plt.plot(mse_epoch, label='NN')
plt.axhline(mse_linear_model, color='red', label='linear',linestyle = '-')
plt.title('Loss history')
plt.legend()
plt.show()

# %%
Y
# Out:
# array([0, 1, 1, 0])

# %%
model.predict(X)
# Out:
# array([0.03994711, 0.96442737, 0.96436524, 0.03771709])

# %%
x1_values = np.linspace(-0.2, 1.2, 100) 
x2_values = np.linspace(-0.2, 1.2, 100)

## agarramos todos los puntos de la grlla para predecir
grid_points = np.array([(x1, x2) for x1 in x1_values for x2 in x2_values])

predictions = model.predict(grid_points)

plt.figure(figsize=(8, 6))
plt.scatter(grid_points[:, 0], grid_points[:, 1], c=predictions, cmap='coolwarm')
plt.colorbar()
plt.scatter(X[:,0],X[:,1], c=Y)
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Mapa de predicciones')

plt.show()

# %% [markdown]
# ### Red neuronal con tensorflow

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD

class NeuralNetworkTensorFlow:
    """
        Este es un modelo simple con TensorFlow para resolver el mismo problema. 
        En esta clase, (1) se construye el modelo.
        (2) Se define como se fitea el modelo
        (3) Y como se hacen las predicciones.
    """
    def __init__(self, learning_rate=0.01, epochs=500):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.model = self.build_model()

    def build_model(self):
        """
            Construye el modelo
            Para construir el modelo es necesario una arquitectura, un optimizador y una función de pérdida.
            La arquitectura se construye con el método Sequential, que basicamente lo que hace es colocar 
            secuencialmente las capas que uno desea.
            Las capas "Dense" son las fully connected dadas en clase.
            Se agrega una capa oculta que recibe un input de tamaño 2,
            y una capa de salida de regresión (una única neurona)
            En todos los casos se define una sigmoidea como función de activación (prueben otras!)

            El optimizador y la función de pérdida se especifican dentro de un compilador.

            Con este método, lo que se devuelve es el modelo sin entrenar, sería equivalente a escribir LinearRegression() 
            en el caso de la regresión lineal.
        """
        model = Sequential([
            Dense(2, activation='relu', input_shape=(2,)),
            Dense(1)
        ])

        model.compile(optimizer=SGD(learning_rate=self.learning_rate), loss='mse')
        ### imprimimos la cantidad de parámetros a modo de ejemplo
        print("n° de parámetros:", model.count_params())
        return model
    
    def fit(self, X, y):
        ### esta es la función donde se entrena el modelo, fijarse que hay un learning rate e iteraciones.
        ### la función que fitea devuelve una historia de pérdida, que vamos a guardar para graficar la evolución.
        X = np.array(X)
        y = np.array(y)
        history = self.model.fit(X, y, epochs=self.epochs, batch_size=32, verbose=0)
        return history.history['loss']

    def predict(self, X):
        X = np.array(X)
        predictions = self.model.predict(X)
        return predictions

# %%
nn_tensorflow = NeuralNetworkTensorFlow(learning_rate=0.1, epochs=1000)
loss_history = nn_tensorflow.fit(X, Y)
# Out:
# n° de parámetros: 9

# %%
plt.plot(loss_history, label='NN')
plt.axhline(mse_linear_model, color='red', label='linear',linestyle = '-')
plt.legend()
plt.show()

# %%
loss_history[-1]
# Out:
# 2.498903590563567e-13

# %%
predictions = nn_tensorflow.predict(X)
print("Predicciones:", predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Predicciones: [[9.0599060e-06]
#  [9.9999285e-01]
#  [9.9999070e-01]
#  [5.2452087e-06]]

# %%
x1_values = np.linspace(0, 1, 100) 
x2_values = np.linspace(0, 1, 100)
grid_points = np.array([(x1, x2) for x1 in x1_values for x2 in x2_values])

predictions = nn_tensorflow.predict(grid_points)

plt.figure(figsize=(8, 6))
plt.scatter(grid_points[:, 0], grid_points[:, 1], c=predictions, cmap='coolwarm')
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Mapa de predicciones')
plt.colorbar()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

class NeuralNetworkPytorch(nn.Module):
    """
        PyTorch requiere definir secuencialmente las funciones de la red neuronal
        En este caso se especifica primero una neurona lineal de 2 inputs y 2 neuronas (output)
        Luego una sigmoidea de activación
        Luego una neurona lineal de 2 inputs y 1 neurona (output)
        y por último una activación.

        Notar que se podría hacer con un bucle, con hiperparámetros de entrada.

        Luego requiere que se defina la acción forward. Internamente, ya conoce como hacer el backward, acorde a las
        funciones que se hayan ido seleccionando.

    """
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(2, 2)
        self.sigmoid1 = nn.Sigmoid()
        self.fc2 = nn.Linear(2, 1)
        #self.sigmoid2 = nn.Sigmoid()

    def forward(self, x):
        x = self.fc1(x)
        x = self.sigmoid1(x)
        x = self.fc2(x)
        #x = self.sigmoid2(x)
        return x

nnet = NeuralNetworkPytorch()
print(nnet)
# Out:
# NeuralNetworkPytorch(
#   (fc1): Linear(in_features=2, out_features=2, bias=True)
#   (sigmoid1): Sigmoid()
#   (fc2): Linear(in_features=2, out_features=1, bias=True)
# )

# %%
print([p for p in nnet.parameters()])

## los parámetros están puestos por capa, e inicializados aleatoriamente al comienzo.
## notarán que son "tensores": básicamente son np.arrays, pero pueden correr con GPU
## puesto que las redes neuronales entrenan una gran cantidad de parámetros, sería óptimo contar con un poder de procesamiento
## computacional interesante (una unidad de procesamiento gráfico que pueda ejecutar la tarea de entrenar estos parámetros
# de forma más eficiente)
# Out:
# [Parameter containing:
# tensor([[ 0.3102,  0.4820],
#         [-0.0866, -0.0797]], requires_grad=True), Parameter containing:
# tensor([0.2035, 0.3615], requires_grad=True), Parameter containing:
# tensor([[ 0.2954, -0.4723]], requires_grad=True), Parameter containing:
# tensor([-0.3359], requires_grad=True)]

# %%
print(sum(p.numel() for p in nnet.parameters())) #numel devuelve la cantidad total de elementos de un tensor
### Cantidad de parámetros.
# Out:
# 9

# %%
### defino mi función de pérdida, MSELoss en este caso
loss_function = torch.nn.MSELoss()
### defino un optimizador, SGD en este caso, con un learning rate, y le decimos cuales son los paarámetros a optimizar.
optimizer = torch.optim.SGD(nnet.parameters(), lr=0.1)

# %%
class MyDataset(Dataset):
    ### esta clase cambia la forma de los datos de entrenamiento
    
    #__init__ guarda el dataset en una variable de clase
    def __init__(self, x, y):
      self.x = x
      self.y = y

    # __len__ define el comportamiento de la función len() sobre el objeto
    def __len__(self):
      return self.x.shape[0]

    # __getitem__ define el comportamiento de los []
    def __getitem__(self, idx):
      return self.x[idx], self.y[idx]

# %%
train_ds = MyDataset(X, Y)

# %%
train_ds[0], train_ds[1], train_ds[2], train_ds[3]
# Out:
# ((array([0, 0]), 0),
#  (array([0, 1]), 1),
#  (array([1, 0]), 1),
#  (array([1, 1]), 0))

# %%
len(train_ds)
# Out:
# 4

# %%
# Pytorch utiliza DataLoader para entregar los dataset de a batches
# en este caso el batch size lo ponemos como 1 porque solo son 4 datos
# pero si se tienen muchos más datos, se toman valores más grandes.
train_dataloader = DataLoader(train_ds, batch_size = 1, shuffle= True)

# %%
# esto es para usar GPU en caso de tenerla disponible
device = "cpu"
if torch.cuda.is_available():
  device = "cuda:0"

device
# Out:
# 'cpu'

# %%
# cantidad de epochs
epochs = 10000

train_loss_by_epoch=[]
valid_loss_by_epoch=[]

# Doble loop algoritmo Mini-Batch
for epoch in range(epochs):
  
    ############################################
    ## Entrenamiento
    ############################################
    nnet.train(True)

    epoch_loss = 0
    epoch_y_hat = []
    epoch_y = []
    
    for i,data in enumerate(train_dataloader):
        # Obtengo los datos del batch de entrenamiento
        x_batch, y_batch = data
        # Copio el batch al dispositivo donde entreno la red neuronal
        x_batch = x_batch.to(device).float()
        y_batch = y_batch.to(device).float().reshape(-1, 1)

        # Paso forward
        # Limpio optimizer para empezar un nuevo cálculo de gradiente
        optimizer.zero_grad()
        nnet_output = nnet(x_batch)
        y_batch_hat = torch.sigmoid(nnet_output)
        
        # Calculo el loss
        loss = loss_function(nnet_output, y_batch)

        # Backpropagation, no hace falta detallar las derivadas como con numpy, pero sí hay que llamar al método.
        loss.backward()

        # Actualizar los parámetros, se utiliza step del optimizador.
        optimizer.step()

        # Almaceno los valores reales y mis predicciones para cálcular las métricas
        epoch_y += list(y_batch.detach().cpu().numpy())
        epoch_y_hat += list(y_batch_hat.detach().cpu().numpy())
        # Acumulo la loss del batch
        epoch_loss = epoch_loss + loss.item()

    # Calculo la media de la loss
    epoch_loss = epoch_loss / len(train_ds)
    # Almaceno la loss de la epoch para graficar
    train_loss_by_epoch.append(epoch_loss)

    ############################################
  ## Impresión de resultados por epoch
  ############################################
    print(f" Epoch {epoch} | " \
        f"Train loss: {epoch_loss:.3f} | ")
# Out:
#  Epoch 0 | Train loss: 0.289 |
#  Epoch 1 | Train loss: 0.285 |
#  Epoch 2 | Train loss: 0.281 |
#  Epoch 3 | Train loss: 0.278 |
#  Epoch 4 | Train loss: 0.275 |
#  Epoch 5 | Train loss: 0.272 |
#  Epoch 6 | Train loss: 0.270 |
#  Epoch 7 | Train loss: 0.268 |
#  Epoch 8 | Train loss: 0.266 |
#  Epoch 9 | Train loss: 0.264 |
#  Epoch 10 | Train loss: 0.263 |
#  Epoch 11 | Train loss: 0.262 |
#  Epoch 12 | Train loss: 0.261 |
#  Epoch 13 | Train loss: 0.260 |
#  Epoch 14 | Train loss: 0.259 |
#  Epoch 15 | Train loss: 0.259 |
#  Epoch 16 | Train loss: 0.258 |
#  Epoch 17 | Train loss: 0.258 |
#  Epoch 18 | Train loss: 0.257 |
#  Epoch 19 | Train loss: 0.257 |
#  Epoch 20 | Train loss: 0.257 |
#  Epoch 21 | Train loss: 0.256 |
#  Epoch 22 | Train loss: 0.256 |
#  Epoch 23 | Train loss: 0.256 |
#  Epoch 24 | Train loss: 0.256 |
#  Epoch 25 | Train loss: 0.256 |
#  Epoch 26 | Train loss: 0.256 |
#  Epoch 27 | Train loss: 0.256 |
#  Epoch 28 | Train loss: 0.256 |
#  Epoch 29 | Train loss: 0.256 |
#  Epoch 30 | Train loss: 0.255 |
#  Epoch 31 | Train loss: 0.255 |
#  Epoch 32 | Train loss: 0.256 |
#  Epoch 33 | Train loss: 0.256 |
#  Epoch 34 | Train loss: 0.255 |
#  Epoch 35 | Train loss: 0.255 |
#  Epoch 36 | Train loss: 0.255 |
#  Epoch 37 | Train loss: 0.255 |
#  Epoch 38 | Train loss: 0.255 |
#  Epoch 39 | Train loss: 0.255 |
#  Epoch 40 | Train loss: 0.255 |
#  Epoch 41 | Train loss: 0.255 |
#  Epoch 42 | Train loss: 0.255 |
#  Epoch 43 | Train loss: 0.255 |
#  Epoch 44 | Train loss: 0.255 |
#  Epoch 45 | Train loss: 0.255 |
#  Epoch 46 | Train loss: 0.255 |
#  Epoch 47 | Train loss: 0.255 |
#  Epoch 48 | Train loss: 0.255 |
#  Epoch 49 | Train loss: 0.255 |
#  Epoch 50 | Train loss: 0.255 |
#  Epoch 51 | Train loss: 0.255 |
#  Epoch 52 | Train loss: 0.255 |
#  Epoch 53 | Train loss: 0.255 |
#  Epoch 54 | Train loss: 0.255 |
#  Epoch 55 | Train loss: 0.255 |
#  Epoch 56 | Train loss: 0.255 |
#  Epoch 57 | Train loss: 0.255 |
#  Epoch 58 | Train loss: 0.255 |
#  Epoch 59 | Train loss: 0.255 |
#  Epoch 60 | Train loss: 0.255 |
#  Epoch 61 | Train loss: 0.255 |
#  Epoch 62 | Train loss: 0.255 |
#  Epoch 63 | Train loss: 0.255 |
#  Epoch 64 | Train loss: 0.255 |
#  Epoch 65 | Train loss: 0.255 |
#  Epoch 66 | Train loss: 0.255 |
#  Epoch 67 | Train loss: 0.255 |
#  Epoch 68 | Train loss: 0.255 |
#  Epoch 69 | Train loss: 0.255 |
#  Epoch 70 | Train loss: 0.255 |
#  Epoch 71 | Train loss: 0.255 |
#  Epoch 72 | Train loss: 0.255 |
#  Epoch 73 | Train loss: 0.255 |
#  Epoch 74 | Train loss: 0.255 |
#  Epoch 75 | Train loss: 0.255 |
#  Epoch 76 | Train loss: 0.255 |
#  Epoch 77 | Train loss: 0.255 |
#  Epoch 78 | Train loss: 0.255 |
#  Epoch 79 | Train loss: 0.255 |
#  Epoch 80 | Train loss: 0.255 |
#  Epoch 81 | Train loss: 0.255 |
#  Epoch 82 | Train loss: 0.255 |
#  Epoch 83 | Train loss: 0.255 |
#  Epoch 84 | Train loss: 0.255 |
#  Epoch 85 | Train loss: 0.255 |
#  Epoch 86 | Train loss: 0.255 |
#  Epoch 87 | Train loss: 0.255 |
#  Epoch 88 | Train loss: 0.255 |
#  Epoch 89 | Train loss: 0.255 |
#  Epoch 90 | Train loss: 0.255 |
#  Epoch 91 | Train loss: 0.255 |
#  Epoch 92 | Train loss: 0.255 |
#  Epoch 93 | Train loss: 0.255 |
#  Epoch 94 | Train loss: 0.255 |
#  Epoch 95 | Train loss: 0.255 |
#  Epoch 96 | Train loss: 0.255 |
#  Epoch 97 | Train loss: 0.255 |
#  Epoch 98 | Train loss: 0.255 |
#  Epoch 99 | Train loss: 0.255 |
#  Epoch 100 | Train loss: 0.255 |
#  Epoch 101 | Train loss: 0.255 |
#  Epoch 102 | Train loss: 0.255 |
#  Epoch 103 | Train loss: 0.255 |
#  Epoch 104 | Train loss: 0.255 |
#  Epoch 105 | Train loss: 0.255 |
#  Epoch 106 | Train loss: 0.255 |
#  Epoch 107 | Train loss: 0.255 |
#  Epoch 108 | Train loss: 0.255 |
#  Epoch 109 | Train loss: 0.255 |
#  Epoch 110 | Train loss: 0.255 |
#  Epoch 111 | Train loss: 0.255 |
#  Epoch 112 | Train loss: 0.255 |
#  Epoch 113 | Train loss: 0.255 |
#  Epoch 114 | Train loss: 0.255 |
#  Epoch 115 | Train loss: 0.255 |
#  Epoch 116 | Train loss: 0.255 |
#  Epoch 117 | Train loss: 0.255 |
#  Epoch 118 | Train loss: 0.255 |
#  Epoch 119 | Train loss: 0.255 |
#  Epoch 120 | Train loss: 0.255 |
#  Epoch 121 | Train loss: 0.255 |
#  Epoch 122 | Train loss: 0.255 |
#  Epoch 123 | Train loss: 0.255 |
#  Epoch 124 | Train loss: 0.255 |
#  Epoch 125 | Train loss: 0.255 |
#  Epoch 126 | Train loss: 0.255 |
#  Epoch 127 | Train loss: 0.255 |
#  Epoch 128 | Train loss: 0.255 |
#  Epoch 129 | Train loss: 0.255 |
#  Epoch 130 | Train loss: 0.255 |
#  Epoch 131 | Train loss: 0.255 |
#  Epoch 132 | Train loss: 0.255 |
#  Epoch 133 | Train loss: 0.255 |
#  Epoch 134 | Train loss: 0.255 |
#  Epoch 135 | Train loss: 0.255 |
#  Epoch 136 | Train loss: 0.255 |
#  Epoch 137 | Train loss: 0.255 |
#  Epoch 138 | Train loss: 0.255 |
#  Epoch 139 | Train loss: 0.255 |
#  Epoch 140 | Train loss: 0.255 |
#  Epoch 141 | Train loss: 0.255 |
#  Epoch 142 | Train loss: 0.255 |
#  Epoch 143 | Train loss: 0.255 |
#  Epoch 144 | Train loss: 0.255 |
#  Epoch 145 | Train loss: 0.255 |
#  Epoch 146 | Train loss: 0.255 |
#  Epoch 147 | Train loss: 0.255 |
#  Epoch 148 | Train loss: 0.255 |
#  Epoch 149 | Train loss: 0.255 |
#  Epoch 150 | Train loss: 0.255 |
#  Epoch 151 | Train loss: 0.255 |
#  Epoch 152 | Train loss: 0.255 |
#  Epoch 153 | Train loss: 0.255 |
#  Epoch 154 | Train loss: 0.255 |
#  Epoch 155 | Train loss: 0.255 |
#  Epoch 156 | Train loss: 0.255 |
#  Epoch 157 | Train loss: 0.255 |
#  Epoch 158 | Train loss: 0.255 |
#  Epoch 159 | Train loss: 0.255 |
#  Epoch 160 | Train loss: 0.255 |
#  Epoch 161 | Train loss: 0.255 |
#  Epoch 162 | Train loss: 0.255 |
#  Epoch 163 | Train loss: 0.255 |
#  Epoch 164 | Train loss: 0.255 |
#  Epoch 165 | Train loss: 0.255 |
#  Epoch 166 | Train loss: 0.255 |
#  Epoch 167 | Train loss: 0.255 |
#  Epoch 168 | Train loss: 0.255 |
#  Epoch 169 | Train loss: 0.255 |
#  Epoch 170 | Train loss: 0.255 |
#  Epoch 171 | Train loss: 0.255 |
#  Epoch 172 | Train loss: 0.255 |
#  Epoch 173 | Train loss: 0.255 |
#  Epoch 174 | Train loss: 0.255 |
#  Epoch 175 | Train loss: 0.255 |
#  Epoch 176 | Train loss: 0.255 |
#  Epoch 177 | Train loss: 0.255 |
#  Epoch 178 | Train loss: 0.255 |
#  Epoch 179 | Train loss: 0.255 |
#  Epoch 180 | Train loss: 0.255 |
#  Epoch 181 | Train loss: 0.255 |
#  Epoch 182 | Train loss: 0.255 |
#  Epoch 183 | Train loss: 0.255 |
#  Epoch 184 | Train loss: 0.255 |
#  Epoch 185 | Train loss: 0.255 |
#  Epoch 186 | Train loss: 0.255 |
#  Epoch 187 | Train loss: 0.255 |
#  Epoch 188 | Train loss: 0.255 |
#  Epoch 189 | Train loss: 0.255 |
#  Epoch 190 | Train loss: 0.255 |
#  Epoch 191 | Train loss: 0.255 |
#  Epoch 192 | Train loss: 0.255 |
#  Epoch 193 | Train loss: 0.255 |
#  Epoch 194 | Train loss: 0.255 |
#  Epoch 195 | Train loss: 0.255 |
#  Epoch 196 | Train loss: 0.255 |
#  Epoch 197 | Train loss: 0.255 |
#  Epoch 198 | Train loss: 0.255 |
#  Epoch 199 | Train loss: 0.255 |
#  Epoch 200 | Train loss: 0.255 |
#  Epoch 201 | Train loss: 0.255 |
#  Epoch 202 | Train loss: 0.255 |
#  Epoch 203 | Train loss: 0.255 |
#  Epoch 204 | Train loss: 0.255 |
#  Epoch 205 | Train loss: 0.255 |
#  Epoch 206 | Train loss: 0.255 |
#  Epoch 207 | Train loss: 0.255 |
#  Epoch 208 | Train loss: 0.255 |
#  Epoch 209 | Train loss: 0.255 |
#  Epoch 210 | Train loss: 0.255 |
#  Epoch 211 | Train loss: 0.255 |
#  Epoch 212 | Train loss: 0.255 |
#  Epoch 213 | Train loss: 0.255 |
#  Epoch 214 | Train loss: 0.255 |
#  Epoch 215 | Train loss: 0.255 |
#  Epoch 216 | Train loss: 0.255 |
#  Epoch 217 | Train loss: 0.255 |
#  Epoch 218 | Train loss: 0.255 |
#  Epoch 219 | Train loss: 0.255 |
#  Epoch 220 | Train loss: 0.255 |
#  Epoch 221 | Train loss: 0.255 |
#  Epoch 222 | Train loss: 0.255 |
#  Epoch 223 | Train loss: 0.255 |
#  Epoch 224 | Train loss: 0.255 |
#  Epoch 225 | Train loss: 0.255 |
#  Epoch 226 | Train loss: 0.255 |
#  Epoch 227 | Train loss: 0.255 |
#  Epoch 228 | Train loss: 0.255 |
#  Epoch 229 | Train loss: 0.255 |
#  Epoch 230 | Train loss: 0.255 |
#  Epoch 231 | Train loss: 0.255 |
#  Epoch 232 | Train loss: 0.255 |
#  Epoch 233 | Train loss: 0.255 |
#  Epoch 234 | Train loss: 0.255 |
#  Epoch 235 | Train loss: 0.255 |
#  Epoch 236 | Train loss: 0.255 |
#  Epoch 237 | Train loss: 0.255 |
#  Epoch 238 | Train loss: 0.255 |
#  Epoch 239 | Train loss: 0.255 |
#  Epoch 240 | Train loss: 0.255 |
#  Epoch 241 | Train loss: 0.255 |
#  Epoch 242 | Train loss: 0.255 |
#  Epoch 243 | Train loss: 0.255 |
#  Epoch 244 | Train loss: 0.255 |
#  Epoch 245 | Train loss: 0.255 |
#  Epoch 246 | Train loss: 0.255 |
#  Epoch 247 | Train loss: 0.255 |
#  Epoch 248 | Train loss: 0.255 |
#  Epoch 249 | Train loss: 0.255 |
#  Epoch 250 | Train loss: 0.255 |
#  Epoch 251 | Train loss: 0.255 |
#  Epoch 252 | Train loss: 0.255 |
#  Epoch 253 | Train loss: 0.255 |
#  Epoch 254 | Train loss: 0.255 |
#  Epoch 255 | Train loss: 0.255 |
#  Epoch 256 | Train loss: 0.255 |
#  Epoch 257 | Train loss: 0.255 |
#  Epoch 258 | Train loss: 0.255 |
#  Epoch 259 | Train loss: 0.255 |
#  Epoch 260 | Train loss: 0.255 |
#  Epoch 261 | Train loss: 0.255 |
#  Epoch 262 | Train loss: 0.255 |
#  Epoch 263 | Train loss: 0.255 |
#  Epoch 264 | Train loss: 0.255 |
#  Epoch 265 | Train loss: 0.255 |
#  Epoch 266 | Train loss: 0.255 |
#  Epoch 267 | Train loss: 0.255 |
#  Epoch 268 | Train loss: 0.255 |
#  Epoch 269 | Train loss: 0.255 |
#  Epoch 270 | Train loss: 0.255 |
#  Epoch 271 | Train loss: 0.255 |
#  Epoch 272 | Train loss: 0.255 |
#  Epoch 273 | Train loss: 0.255 |
#  Epoch 274 | Train loss: 0.255 |
#  Epoch 275 | Train loss: 0.255 |
#  Epoch 276 | Train loss: 0.255 |
#  Epoch 277 | Train loss: 0.255 |
#  Epoch 278 | Train loss: 0.255 |
#  Epoch 279 | Train loss: 0.255 |
#  Epoch 280 | Train loss: 0.255 |
#  Epoch 281 | Train loss: 0.255 |
#  Epoch 282 | Train loss: 0.255 |
#  Epoch 283 | Train loss: 0.255 |
#  Epoch 284 | Train loss: 0.255 |
#  Epoch 285 | Train loss: 0.255 |
#  Epoch 286 | Train loss: 0.255 |
#  Epoch 287 | Train loss: 0.255 |
#  Epoch 288 | Train loss: 0.255 |
#  Epoch 289 | Train loss: 0.255 |
#  Epoch 290 | Train loss: 0.255 |
#  Epoch 291 | Train loss: 0.255 |
#  Epoch 292 | Train loss: 0.255 |
#  Epoch 293 | Train loss: 0.255 |
#  Epoch 294 | Train loss: 0.255 |
#  Epoch 295 | Train loss: 0.255 |
#  Epoch 296 | Train loss: 0.255 |
#  Epoch 297 | Train loss: 0.255 |
#  Epoch 298 | Train loss: 0.255 |
#  Epoch 299 | Train loss: 0.255 |
#  Epoch 300 | Train loss: 0.255 |
#  Epoch 301 | Train loss: 0.255 |
#  Epoch 302 | Train loss: 0.255 |
#  Epoch 303 | Train loss: 0.255 |
#  Epoch 304 | Train loss: 0.255 |
#  Epoch 305 | Train loss: 0.255 |
#  Epoch 306 | Train loss: 0.255 |
#  Epoch 307 | Train loss: 0.255 |
#  Epoch 308 | Train loss: 0.255 |
#  Epoch 309 | Train loss: 0.255 |
#  Epoch 310 | Train loss: 0.255 |
#  Epoch 311 | Train loss: 0.255 |
#  Epoch 312 | Train loss: 0.255 |
#  Epoch 313 | Train loss: 0.255 |
#  Epoch 314 | Train loss: 0.255 |
#  Epoch 315 | Train loss: 0.255 |
#  Epoch 316 | Train loss: 0.255 |
#  Epoch 317 | Train loss: 0.255 |
#  Epoch 318 | Train loss: 0.255 |
#  Epoch 319 | Train loss: 0.255 |
#  Epoch 320 | Train loss: 0.255 |
#  Epoch 321 | Train loss: 0.255 |
#  Epoch 322 | Train loss: 0.255 |
#  Epoch 323 | Train loss: 0.255 |
#  Epoch 324 | Train loss: 0.255 |
#  Epoch 325 | Train loss: 0.255 |
#  Epoch 326 | Train loss: 0.255 |
#  Epoch 327 | Train loss: 0.255 |
#  Epoch 328 | Train loss: 0.255 |
#  Epoch 329 | Train loss: 0.255 |
#  Epoch 330 | Train loss: 0.255 |
#  Epoch 331 | Train loss: 0.255 |
#  Epoch 332 | Train loss: 0.255 |
#  Epoch 333 | Train loss: 0.255 |
#  Epoch 334 | Train loss: 0.255 |
#  Epoch 335 | Train loss: 0.255 |
#  Epoch 336 | Train loss: 0.255 |
#  Epoch 337 | Train loss: 0.255 |
#  Epoch 338 | Train loss: 0.255 |
#  Epoch 339 | Train loss: 0.255 |
#  Epoch 340 | Train loss: 0.255 |
#  Epoch 341 | Train loss: 0.255 |
#  Epoch 342 | Train loss: 0.255 |
#  Epoch 343 | Train loss: 0.255 |
#  Epoch 344 | Train loss: 0.255 |
#  Epoch 345 | Train loss: 0.255 |
#  Epoch 346 | Train loss: 0.255 |
#  Epoch 347 | Train loss: 0.255 |
#  Epoch 348 | Train loss: 0.255 |
#  Epoch 349 | Train loss: 0.255 |
#  Epoch 350 | Train loss: 0.255 |
#  Epoch 351 | Train loss: 0.255 |
#  Epoch 352 | Train loss: 0.255 |
#  Epoch 353 | Train loss: 0.255 |
#  Epoch 354 | Train loss: 0.255 |
#  Epoch 355 | Train loss: 0.255 |
#  Epoch 356 | Train loss: 0.255 |
#  Epoch 357 | Train loss: 0.255 |
#  Epoch 358 | Train loss: 0.255 |
#  Epoch 359 | Train loss: 0.255 |
#  Epoch 360 | Train loss: 0.255 |
#  Epoch 361 | Train loss: 0.255 |
#  Epoch 362 | Train loss: 0.255 |
#  Epoch 363 | Train loss: 0.255 |
#  Epoch 364 | Train loss: 0.255 |
#  Epoch 365 | Train loss: 0.255 |
#  Epoch 366 | Train loss: 0.255 |
#  Epoch 367 | Train loss: 0.255 |
#  Epoch 368 | Train loss: 0.255 |
#  Epoch 369 | Train loss: 0.255 |
#  Epoch 370 | Train loss: 0.255 |
#  Epoch 371 | Train loss: 0.255 |
#  Epoch 372 | Train loss: 0.255 |
#  Epoch 373 | Train loss: 0.255 |
#  Epoch 374 | Train loss: 0.255 |
#  Epoch 375 | Train loss: 0.255 |
#  Epoch 376 | Train loss: 0.255 |
#  Epoch 377 | Train loss: 0.255 |
#  Epoch 378 | Train loss: 0.255 |
#  Epoch 379 | Train loss: 0.255 |
#  Epoch 380 | Train loss: 0.255 |
#  Epoch 381 | Train loss: 0.255 |
#  Epoch 382 | Train loss: 0.255 |
#  Epoch 383 | Train loss: 0.255 |
#  Epoch 384 | Train loss: 0.255 |
#  Epoch 385 | Train loss: 0.255 |
#  Epoch 386 | Train loss: 0.255 |
#  Epoch 387 | Train loss: 0.255 |
#  Epoch 388 | Train loss: 0.255 |
#  Epoch 389 | Train loss: 0.255 |
#  Epoch 390 | Train loss: 0.255 |
#  Epoch 391 | Train loss: 0.255 |
#  Epoch 392 | Train loss: 0.255 |
#  Epoch 393 | Train loss: 0.255 |
#  Epoch 394 | Train loss: 0.255 |
#  Epoch 395 | Train loss: 0.255 |
#  Epoch 396 | Train loss: 0.255 |
#  Epoch 397 | Train loss: 0.255 |
#  Epoch 398 | Train loss: 0.255 |
#  Epoch 399 | Train loss: 0.255 |
#  Epoch 400 | Train loss: 0.255 |
#  Epoch 401 | Train loss: 0.255 |
#  Epoch 402 | Train loss: 0.255 |
#  Epoch 403 | Train loss: 0.255 |
#  Epoch 404 | Train loss: 0.255 |
#  Epoch 405 | Train loss: 0.255 |
#  Epoch 406 | Train loss: 0.255 |
#  Epoch 407 | Train loss: 0.255 |
#  Epoch 408 | Train loss: 0.255 |
#  Epoch 409 | Train loss: 0.255 |
#  Epoch 410 | Train loss: 0.255 |
#  Epoch 411 | Train loss: 0.255 |
#  Epoch 412 | Train loss: 0.255 |
#  Epoch 413 | Train loss: 0.255 |
#  Epoch 414 | Train loss: 0.255 |
#  Epoch 415 | Train loss: 0.255 |
#  Epoch 416 | Train loss: 0.255 |
#  Epoch 417 | Train loss: 0.255 |
#  Epoch 418 | Train loss: 0.255 |
#  Epoch 419 | Train loss: 0.255 |
#  Epoch 420 | Train loss: 0.255 |
#  Epoch 421 | Train loss: 0.255 |
#  Epoch 422 | Train loss: 0.255 |
#  Epoch 423 | Train loss: 0.255 |
#  Epoch 424 | Train loss: 0.255 |
#  Epoch 425 | Train loss: 0.255 |
#  Epoch 426 | Train loss: 0.255 |
#  Epoch 427 | Train loss: 0.255 |
#  Epoch 428 | Train loss: 0.255 |
#  Epoch 429 | Train loss: 0.255 |
#  Epoch 430 | Train loss: 0.255 |
#  Epoch 431 | Train loss: 0.255 |
#  Epoch 432 | Train loss: 0.255 |
#  Epoch 433 | Train loss: 0.255 |
#  Epoch 434 | Train loss: 0.255 |
#  Epoch 435 | Train loss: 0.255 |
#  Epoch 436 | Train loss: 0.255 |
#  Epoch 437 | Train loss: 0.255 |
#  Epoch 438 | Train loss: 0.255 |
#  Epoch 439 | Train loss: 0.255 |
#  Epoch 440 | Train loss: 0.255 |
#  Epoch 441 | Train loss: 0.255 |
#  Epoch 442 | Train loss: 0.255 |
#  Epoch 443 | Train loss: 0.255 |
#  Epoch 444 | Train loss: 0.255 |
#  Epoch 445 | Train loss: 0.255 |
#  Epoch 446 | Train loss: 0.255 |
#  Epoch 447 | Train loss: 0.255 |
#  Epoch 448 | Train loss: 0.255 |
#  Epoch 449 | Train loss: 0.255 |
#  Epoch 450 | Train loss: 0.255 |
#  Epoch 451 | Train loss: 0.255 |
#  Epoch 452 | Train loss: 0.255 |
#  Epoch 453 | Train loss: 0.255 |
#  Epoch 454 | Train loss: 0.255 |
#  Epoch 455 | Train loss: 0.255 |
#  Epoch 456 | Train loss: 0.255 |
#  Epoch 457 | Train loss: 0.255 |
#  Epoch 458 | Train loss: 0.255 |
#  Epoch 459 | Train loss: 0.255 |
#  Epoch 460 | Train loss: 0.255 |
#  Epoch 461 | Train loss: 0.255 |
#  Epoch 462 | Train loss: 0.255 |
#  Epoch 463 | Train loss: 0.255 |
#  Epoch 464 | Train loss: 0.255 |
#  Epoch 465 | Train loss: 0.255 |
#  Epoch 466 | Train loss: 0.255 |
#  Epoch 467 | Train loss: 0.255 |
#  Epoch 468 | Train loss: 0.255 |
#  Epoch 469 | Train loss: 0.255 |
#  Epoch 470 | Train loss: 0.255 |
#  Epoch 471 | Train loss: 0.255 |
#  Epoch 472 | Train loss: 0.255 |
#  Epoch 473 | Train loss: 0.255 |
#  Epoch 474 | Train loss: 0.255 |
#  Epoch 475 | Train loss: 0.255 |
#  Epoch 476 | Train loss: 0.255 |
#  Epoch 477 | Train loss: 0.255 |
#  Epoch 478 | Train loss: 0.255 |
#  Epoch 479 | Train loss: 0.255 |
#  Epoch 480 | Train loss: 0.255 |
#  Epoch 481 | Train loss: 0.255 |
#  Epoch 482 | Train loss: 0.255 |
#  Epoch 483 | Train loss: 0.255 |
#  Epoch 484 | Train loss: 0.255 |
#  Epoch 485 | Train loss: 0.255 |
#  Epoch 486 | Train loss: 0.255 |
#  Epoch 487 | Train loss: 0.255 |
#  Epoch 488 | Train loss: 0.255 |
#  Epoch 489 | Train loss: 0.255 |
#  Epoch 490 | Train loss: 0.255 |
#  Epoch 491 | Train loss: 0.255 |
#  Epoch 492 | Train loss: 0.255 |
#  Epoch 493 | Train loss: 0.255 |
#  Epoch 494 | Train loss: 0.255 |
#  Epoch 495 | Train loss: 0.255 |
#  Epoch 496 | Train loss: 0.255 |
#  Epoch 497 | Train loss: 0.255 |
#  Epoch 498 | Train loss: 0.255 |
#  Epoch 499 | Train loss: 0.255 |
#  Epoch 500 | Train loss: 0.255 |
#  Epoch 501 | Train loss: 0.255 |
#  Epoch 502 | Train loss: 0.255 |
#  Epoch 503 | Train loss: 0.255 |
#  Epoch 504 | Train loss: 0.255 |
#  Epoch 505 | Train loss: 0.255 |
#  Epoch 506 | Train loss: 0.255 |
#  Epoch 507 | Train loss: 0.255 |
#  Epoch 508 | Train loss: 0.255 |
#  Epoch 509 | Train loss: 0.255 |
#  Epoch 510 | Train loss: 0.255 |
#  Epoch 511 | Train loss: 0.255 |
#  Epoch 512 | Train loss: 0.255 |
#  Epoch 513 | Train loss: 0.255 |
#  Epoch 514 | Train loss: 0.255 |
#  Epoch 515 | Train loss: 0.255 |
#  Epoch 516 | Train loss: 0.255 |
#  Epoch 517 | Train loss: 0.255 |
#  Epoch 518 | Train loss: 0.255 |
#  Epoch 519 | Train loss: 0.255 |
#  Epoch 520 | Train loss: 0.255 |
#  Epoch 521 | Train loss: 0.255 |
#  Epoch 522 | Train loss: 0.255 |
#  Epoch 523 | Train loss: 0.255 |
#  Epoch 524 | Train loss: 0.255 |
#  Epoch 525 | Train loss: 0.255 |
#  Epoch 526 | Train loss: 0.255 |
#  Epoch 527 | Train loss: 0.255 |
#  Epoch 528 | Train loss: 0.255 |
#  Epoch 529 | Train loss: 0.255 |
#  Epoch 530 | Train loss: 0.255 |
#  Epoch 531 | Train loss: 0.255 |
#  Epoch 532 | Train loss: 0.255 |
#  Epoch 533 | Train loss: 0.255 |
#  Epoch 534 | Train loss: 0.255 |
#  Epoch 535 | Train loss: 0.255 |
#  Epoch 536 | Train loss: 0.255 |
#  Epoch 537 | Train loss: 0.255 |
#  Epoch 538 | Train loss: 0.255 |
#  Epoch 539 | Train loss: 0.255 |
#  Epoch 540 | Train loss: 0.255 |
#  Epoch 541 | Train loss: 0.255 |
#  Epoch 542 | Train loss: 0.255 |
#  Epoch 543 | Train loss: 0.255 |
#  Epoch 544 | Train loss: 0.255 |
#  Epoch 545 | Train loss: 0.255 |
#  Epoch 546 | Train loss: 0.255 |
#  Epoch 547 | Train loss: 0.255 |
#  Epoch 548 | Train loss: 0.255 |
#  Epoch 549 | Train loss: 0.255 |
#  Epoch 550 | Train loss: 0.255 |
#  Epoch 551 | Train loss: 0.255 |
#  Epoch 552 | Train loss: 0.255 |
#  Epoch 553 | Train loss: 0.255 |
#  Epoch 554 | Train loss: 0.255 |
#  Epoch 555 | Train loss: 0.255 |
#  Epoch 556 | Train loss: 0.255 |
#  Epoch 557 | Train loss: 0.255 |
#  Epoch 558 | Train loss: 0.255 |
#  Epoch 559 | Train loss: 0.255 |
#  Epoch 560 | Train loss: 0.255 |
#  Epoch 561 | Train loss: 0.255 |
#  Epoch 562 | Train loss: 0.255 |
#  Epoch 563 | Train loss: 0.255 |
#  Epoch 564 | Train loss: 0.255 |
#  Epoch 565 | Train loss: 0.255 |
#  Epoch 566 | Train loss: 0.255 |
#  Epoch 567 | Train loss: 0.255 |
#  Epoch 568 | Train loss: 0.255 |
#  Epoch 569 | Train loss: 0.255 |
#  Epoch 570 | Train loss: 0.255 |
#  Epoch 571 | Train loss: 0.255 |
#  Epoch 572 | Train loss: 0.255 |
#  Epoch 573 | Train loss: 0.255 |
#  Epoch 574 | Train loss: 0.255 |
#  Epoch 575 | Train loss: 0.255 |
#  Epoch 576 | Train loss: 0.255 |
#  Epoch 577 | Train loss: 0.255 |
#  Epoch 578 | Train loss: 0.255 |
#  Epoch 579 | Train loss: 0.255 |
#  Epoch 580 | Train loss: 0.255 |
#  Epoch 581 | Train loss: 0.255 |
#  Epoch 582 | Train loss: 0.255 |
#  Epoch 583 | Train loss: 0.255 |
#  Epoch 584 | Train loss: 0.255 |
#  Epoch 585 | Train loss: 0.255 |
#  Epoch 586 | Train loss: 0.255 |
#  Epoch 587 | Train loss: 0.255 |
#  Epoch 588 | Train loss: 0.255 |
#  Epoch 589 | Train loss: 0.255 |
#  Epoch 590 | Train loss: 0.255 |
#  Epoch 591 | Train loss: 0.255 |
#  Epoch 592 | Train loss: 0.255 |
#  Epoch 593 | Train loss: 0.255 |
#  Epoch 594 | Train loss: 0.255 |
#  Epoch 595 | Train loss: 0.255 |
#  Epoch 596 | Train loss: 0.255 |
#  Epoch 597 | Train loss: 0.255 |
#  Epoch 598 | Train loss: 0.255 |
#  Epoch 599 | Train loss: 0.255 |
#  Epoch 600 | Train loss: 0.255 |
#  Epoch 601 | Train loss: 0.255 |
#  Epoch 602 | Train loss: 0.255 |
#  Epoch 603 | Train loss: 0.255 |
#  Epoch 604 | Train loss: 0.255 |
#  Epoch 605 | Train loss: 0.255 |
#  Epoch 606 | Train loss: 0.255 |
#  Epoch 607 | Train loss: 0.255 |
#  Epoch 608 | Train loss: 0.255 |
#  Epoch 609 | Train loss: 0.255 |
#  Epoch 610 | Train loss: 0.255 |
#  Epoch 611 | Train loss: 0.255 |
#  Epoch 612 | Train loss: 0.255 |
#  Epoch 613 | Train loss: 0.255 |
#  Epoch 614 | Train loss: 0.255 |
#  Epoch 615 | Train loss: 0.255 |
#  Epoch 616 | Train loss: 0.255 |
#  Epoch 617 | Train loss: 0.255 |
#  Epoch 618 | Train loss: 0.255 |
#  Epoch 619 | Train loss: 0.255 |
#  Epoch 620 | Train loss: 0.255 |
#  Epoch 621 | Train loss: 0.255 |
#  Epoch 622 | Train loss: 0.255 |
#  Epoch 623 | Train loss: 0.255 |
#  Epoch 624 | Train loss: 0.255 |
#  Epoch 625 | Train loss: 0.255 |
#  Epoch 626 | Train loss: 0.255 |
#  Epoch 627 | Train loss: 0.255 |
#  Epoch 628 | Train loss: 0.255 |
#  Epoch 629 | Train loss: 0.255 |
#  Epoch 630 | Train loss: 0.255 |
#  Epoch 631 | Train loss: 0.255 |
#  Epoch 632 | Train loss: 0.255 |
#  Epoch 633 | Train loss: 0.255 |
#  Epoch 634 | Train loss: 0.255 |
#  Epoch 635 | Train loss: 0.255 |
#  Epoch 636 | Train loss: 0.255 |
#  Epoch 637 | Train loss: 0.255 |
#  Epoch 638 | Train loss: 0.255 |
#  Epoch 639 | Train loss: 0.255 |
#  Epoch 640 | Train loss: 0.255 |
#  Epoch 641 | Train loss: 0.255 |
#  Epoch 642 | Train loss: 0.255 |
#  Epoch 643 | Train loss: 0.255 |
#  Epoch 644 | Train loss: 0.255 |
#  Epoch 645 | Train loss: 0.255 |
#  Epoch 646 | Train loss: 0.255 |
#  Epoch 647 | Train loss: 0.255 |
#  Epoch 648 | Train loss: 0.255 |
#  Epoch 649 | Train loss: 0.255 |
#  Epoch 650 | Train loss: 0.255 |
#  Epoch 651 | Train loss: 0.255 |
#  Epoch 652 | Train loss: 0.255 |
#  Epoch 653 | Train loss: 0.255 |
#  Epoch 654 | Train loss: 0.255 |
#  Epoch 655 | Train loss: 0.255 |
#  Epoch 656 | Train loss: 0.255 |
#  Epoch 657 | Train loss: 0.255 |
#  Epoch 658 | Train loss: 0.255 |
#  Epoch 659 | Train loss: 0.255 |
#  Epoch 660 | Train loss: 0.255 |
#  Epoch 661 | Train loss: 0.255 |
#  Epoch 662 | Train loss: 0.255 |
#  Epoch 663 | Train loss: 0.255 |
#  Epoch 664 | Train loss: 0.255 |
#  Epoch 665 | Train loss: 0.255 |
#  Epoch 666 | Train loss: 0.255 |
#  Epoch 667 | Train loss: 0.255 |
#  Epoch 668 | Train loss: 0.255 |
#  Epoch 669 | Train loss: 0.255 |
#  Epoch 670 | Train loss: 0.255 |
#  Epoch 671 | Train loss: 0.255 |
#  Epoch 672 | Train loss: 0.255 |
#  Epoch 673 | Train loss: 0.255 |
#  Epoch 674 | Train loss: 0.255 |
#  Epoch 675 | Train loss: 0.255 |
#  Epoch 676 | Train loss: 0.255 |
#  Epoch 677 | Train loss: 0.255 |
#  Epoch 678 | Train loss: 0.255 |
#  Epoch 679 | Train loss: 0.255 |
#  Epoch 680 | Train loss: 0.255 |
#  Epoch 681 | Train loss: 0.255 |
#  Epoch 682 | Train loss: 0.255 |
#  Epoch 683 | Train loss: 0.255 |
#  Epoch 684 | Train loss: 0.255 |
#  Epoch 685 | Train loss: 0.255 |
#  Epoch 686 | Train loss: 0.255 |
#  Epoch 687 | Train loss: 0.255 |
#  Epoch 688 | Train loss: 0.255 |
#  Epoch 689 | Train loss: 0.255 |
#  Epoch 690 | Train loss: 0.255 |
#  Epoch 691 | Train loss: 0.255 |
#  Epoch 692 | Train loss: 0.255 |
#  Epoch 693 | Train loss: 0.255 |
#  Epoch 694 | Train loss: 0.255 |
#  Epoch 695 | Train loss: 0.255 |
#  Epoch 696 | Train loss: 0.255 |
#  Epoch 697 | Train loss: 0.255 |
#  Epoch 698 | Train loss: 0.255 |
#  Epoch 699 | Train loss: 0.255 |
#  Epoch 700 | Train loss: 0.255 |
#  Epoch 701 | Train loss: 0.255 |
#  Epoch 702 | Train loss: 0.255 |
#  Epoch 703 | Train loss: 0.255 |
#  Epoch 704 | Train loss: 0.255 |
#  Epoch 705 | Train loss: 0.255 |
#  Epoch 706 | Train loss: 0.255 |
#  Epoch 707 | Train loss: 0.255 |
#  Epoch 708 | Train loss: 0.255 |
#  Epoch 709 | Train loss: 0.255 |
#  Epoch 710 | Train loss: 0.255 |
#  Epoch 711 | Train loss: 0.255 |
#  Epoch 712 | Train loss: 0.255 |
#  Epoch 713 | Train loss: 0.255 |
#  Epoch 714 | Train loss: 0.255 |
#  Epoch 715 | Train loss: 0.255 |
#  Epoch 716 | Train loss: 0.255 |
#  Epoch 717 | Train loss: 0.255 |
#  Epoch 718 | Train loss: 0.255 |
#  Epoch 719 | Train loss: 0.255 |
#  Epoch 720 | Train loss: 0.255 |
#  Epoch 721 | Train loss: 0.255 |
#  Epoch 722 | Train loss: 0.255 |
#  Epoch 723 | Train loss: 0.255 |
#  Epoch 724 | Train loss: 0.255 |
#  Epoch 725 | Train loss: 0.255 |
#  Epoch 726 | Train loss: 0.255 |
#  Epoch 727 | Train loss: 0.255 |
#  Epoch 728 | Train loss: 0.255 |
#  Epoch 729 | Train loss: 0.255 |
#  Epoch 730 | Train loss: 0.255 |
#  Epoch 731 | Train loss: 0.255 |
#  Epoch 732 | Train loss: 0.255 |
#  Epoch 733 | Train loss: 0.255 |
#  Epoch 734 | Train loss: 0.255 |
#  Epoch 735 | Train loss: 0.255 |
#  Epoch 736 | Train loss: 0.255 |
#  Epoch 737 | Train loss: 0.255 |
#  Epoch 738 | Train loss: 0.255 |
#  Epoch 739 | Train loss: 0.255 |
#  Epoch 740 | Train loss: 0.255 |
#  Epoch 741 | Train loss: 0.255 |
#  Epoch 742 | Train loss: 0.255 |
#  Epoch 743 | Train loss: 0.255 |
#  Epoch 744 | Train loss: 0.255 |
#  Epoch 745 | Train loss: 0.255 |
#  Epoch 746 | Train loss: 0.255 |
#  Epoch 747 | Train loss: 0.255 |
#  Epoch 748 | Train loss: 0.255 |
#  Epoch 749 | Train loss: 0.255 |
#  Epoch 750 | Train loss: 0.255 |
#  Epoch 751 | Train loss: 0.255 |
#  Epoch 752 | Train loss: 0.255 |
#  Epoch 753 | Train loss: 0.255 |
#  Epoch 754 | Train loss: 0.255 |
#  Epoch 755 | Train loss: 0.255 |
#  Epoch 756 | Train loss: 0.255 |
#  Epoch 757 | Train loss: 0.255 |
#  Epoch 758 | Train loss: 0.255 |
#  Epoch 759 | Train loss: 0.255 |
#  Epoch 760 | Train loss: 0.255 |
#  Epoch 761 | Train loss: 0.255 |
#  Epoch 762 | Train loss: 0.255 |
#  Epoch 763 | Train loss: 0.255 |
#  Epoch 764 | Train loss: 0.255 |
#  Epoch 765 | Train loss: 0.255 |
#  Epoch 766 | Train loss: 0.255 |
#  Epoch 767 | Train loss: 0.255 |
#  Epoch 768 | Train loss: 0.255 |
#  Epoch 769 | Train loss: 0.255 |
#  Epoch 770 | Train loss: 0.255 |
#  Epoch 771 | Train loss: 0.255 |
#  Epoch 772 | Train loss: 0.255 |
#  Epoch 773 | Train loss: 0.255 |
#  Epoch 774 | Train loss: 0.255 |
#  Epoch 775 | Train loss: 0.255 |
#  Epoch 776 | Train loss: 0.255 |
#  Epoch 777 | Train loss: 0.255 |
#  Epoch 778 | Train loss: 0.255 |
#  Epoch 779 | Train loss: 0.255 |
#  Epoch 780 | Train loss: 0.255 |
#  Epoch 781 | Train loss: 0.255 |
#  Epoch 782 | Train loss: 0.255 |
#  Epoch 783 | Train loss: 0.255 |
#  Epoch 784 | Train loss: 0.255 |
#  Epoch 785 | Train loss: 0.255 |
#  Epoch 786 | Train loss: 0.255 |
#  Epoch 787 | Train loss: 0.255 |
#  Epoch 788 | Train loss: 0.255 |
#  Epoch 789 | Train loss: 0.255 |
#  Epoch 790 | Train loss: 0.255 |
#  Epoch 791 | Train loss: 0.255 |
#  Epoch 792 | Train loss: 0.255 |
#  Epoch 793 | Train loss: 0.255 |
#  Epoch 794 | Train loss: 0.255 |
#  Epoch 795 | Train loss: 0.255 |
#  Epoch 796 | Train loss: 0.255 |
#  Epoch 797 | Train loss: 0.255 |
#  Epoch 798 | Train loss: 0.255 |
#  Epoch 799 | Train loss: 0.255 |
#  Epoch 800 | Train loss: 0.255 |
#  Epoch 801 | Train loss: 0.255 |
#  Epoch 802 | Train loss: 0.255 |
#  Epoch 803 | Train loss: 0.255 |
#  Epoch 804 | Train loss: 0.255 |
#  Epoch 805 | Train loss: 0.255 |
#  Epoch 806 | Train loss: 0.255 |
#  Epoch 807 | Train loss: 0.255 |
#  Epoch 808 | Train loss: 0.255 |
#  Epoch 809 | Train loss: 0.255 |
#  Epoch 810 | Train loss: 0.255 |
#  Epoch 811 | Train loss: 0.255 |
#  Epoch 812 | Train loss: 0.255 |
#  Epoch 813 | Train loss: 0.255 |
#  Epoch 814 | Train loss: 0.255 |
#  Epoch 815 | Train loss: 0.255 |
#  Epoch 816 | Train loss: 0.255 |
#  Epoch 817 | Train loss: 0.255 |
#  Epoch 818 | Train loss: 0.255 |
#  Epoch 819 | Train loss: 0.255 |
#  Epoch 820 | Train loss: 0.255 |
#  Epoch 821 | Train loss: 0.255 |
#  Epoch 822 | Train loss: 0.255 |
#  Epoch 823 | Train loss: 0.255 |
#  Epoch 824 | Train loss: 0.255 |
#  Epoch 825 | Train loss: 0.255 |
#  Epoch 826 | Train loss: 0.255 |
#  Epoch 827 | Train loss: 0.255 |
#  Epoch 828 | Train loss: 0.255 |
#  Epoch 829 | Train loss: 0.255 |
#  Epoch 830 | Train loss: 0.255 |
#  Epoch 831 | Train loss: 0.255 |
#  Epoch 832 | Train loss: 0.255 |
#  Epoch 833 | Train loss: 0.255 |
#  Epoch 834 | Train loss: 0.255 |
#  Epoch 835 | Train loss: 0.255 |
#  Epoch 836 | Train loss: 0.255 |
#  Epoch 837 | Train loss: 0.255 |
#  Epoch 838 | Train loss: 0.255 |
#  Epoch 839 | Train loss: 0.255 |
#  Epoch 840 | Train loss: 0.255 |
#  Epoch 841 | Train loss: 0.255 |
#  Epoch 842 | Train loss: 0.255 |
#  Epoch 843 | Train loss: 0.255 |
#  Epoch 844 | Train loss: 0.255 |
#  Epoch 845 | Train loss: 0.255 |
#  Epoch 846 | Train loss: 0.255 |
#  Epoch 847 | Train loss: 0.255 |
#  Epoch 848 | Train loss: 0.255 |
#  Epoch 849 | Train loss: 0.255 |
#  Epoch 850 | Train loss: 0.255 |
#  Epoch 851 | Train loss: 0.255 |
#  Epoch 852 | Train loss: 0.255 |
#  Epoch 853 | Train loss: 0.255 |
#  Epoch 854 | Train loss: 0.255 |
#  Epoch 855 | Train loss: 0.255 |
#  Epoch 856 | Train loss: 0.255 |
#  Epoch 857 | Train loss: 0.255 |
#  Epoch 858 | Train loss: 0.255 |
#  Epoch 859 | Train loss: 0.255 |
#  Epoch 860 | Train loss: 0.255 |
#  Epoch 861 | Train loss: 0.255 |
#  Epoch 862 | Train loss: 0.255 |
#  Epoch 863 | Train loss: 0.255 |
#  Epoch 864 | Train loss: 0.255 |
#  Epoch 865 | Train loss: 0.255 |
#  Epoch 866 | Train loss: 0.255 |
#  Epoch 867 | Train loss: 0.255 |
#  Epoch 868 | Train loss: 0.255 |
#  Epoch 869 | Train loss: 0.255 |
#  Epoch 870 | Train loss: 0.255 |
#  Epoch 871 | Train loss: 0.255 |
#  Epoch 872 | Train loss: 0.255 |
#  Epoch 873 | Train loss: 0.255 |
#  Epoch 874 | Train loss: 0.255 |
#  Epoch 875 | Train loss: 0.255 |
#  Epoch 876 | Train loss: 0.255 |
#  Epoch 877 | Train loss: 0.255 |
#  Epoch 878 | Train loss: 0.255 |
#  Epoch 879 | Train loss: 0.255 |
#  Epoch 880 | Train loss: 0.255 |
#  Epoch 881 | Train loss: 0.255 |
#  Epoch 882 | Train loss: 0.255 |
#  Epoch 883 | Train loss: 0.255 |
#  Epoch 884 | Train loss: 0.255 |
#  Epoch 885 | Train loss: 0.255 |
#  Epoch 886 | Train loss: 0.255 |
#  Epoch 887 | Train loss: 0.255 |
#  Epoch 888 | Train loss: 0.255 |
#  Epoch 889 | Train loss: 0.255 |
#  Epoch 890 | Train loss: 0.255 |
#  Epoch 891 | Train loss: 0.255 |
#  Epoch 892 | Train loss: 0.255 |
#  Epoch 893 | Train loss: 0.255 |
#  Epoch 894 | Train loss: 0.255 |
#  Epoch 895 | Train loss: 0.255 |
#  Epoch 896 | Train loss: 0.255 |
#  Epoch 897 | Train loss: 0.255 |
#  Epoch 898 | Train loss: 0.255 |
#  Epoch 899 | Train loss: 0.255 |
#  Epoch 900 | Train loss: 0.255 |
#  Epoch 901 | Train loss: 0.255 |
#  Epoch 902 | Train loss: 0.255 |
#  Epoch 903 | Train loss: 0.255 |
#  Epoch 904 | Train loss: 0.255 |
#  Epoch 905 | Train loss: 0.255 |
#  Epoch 906 | Train loss: 0.255 |
#  Epoch 907 | Train loss: 0.255 |
#  Epoch 908 | Train loss: 0.255 |
#  Epoch 909 | Train loss: 0.255 |
#  Epoch 910 | Train loss: 0.255 |
#  Epoch 911 | Train loss: 0.255 |
#  Epoch 912 | Train loss: 0.255 |
#  Epoch 913 | Train loss: 0.255 |
#  Epoch 914 | Train loss: 0.255 |
#  Epoch 915 | Train loss: 0.255 |
#  Epoch 916 | Train loss: 0.255 |
#  Epoch 917 | Train loss: 0.255 |
#  Epoch 918 | Train loss: 0.255 |
#  Epoch 919 | Train loss: 0.255 |
#  Epoch 920 | Train loss: 0.255 |
#  Epoch 921 | Train loss: 0.255 |
#  Epoch 922 | Train loss: 0.255 |
#  Epoch 923 | Train loss: 0.255 |
#  Epoch 924 | Train loss: 0.255 |
#  Epoch 925 | Train loss: 0.255 |
#  Epoch 926 | Train loss: 0.255 |
#  Epoch 927 | Train loss: 0.255 |
#  Epoch 928 | Train loss: 0.255 |
#  Epoch 929 | Train loss: 0.255 |
#  Epoch 930 | Train loss: 0.255 |
#  Epoch 931 | Train loss: 0.255 |
#  Epoch 932 | Train loss: 0.255 |
#  Epoch 933 | Train loss: 0.255 |
#  Epoch 934 | Train loss: 0.255 |
#  Epoch 935 | Train loss: 0.255 |
#  Epoch 936 | Train loss: 0.255 |
#  Epoch 937 | Train loss: 0.255 |
#  Epoch 938 | Train loss: 0.255 |
#  Epoch 939 | Train loss: 0.255 |
#  Epoch 940 | Train loss: 0.255 |
#  Epoch 941 | Train loss: 0.255 |
#  Epoch 942 | Train loss: 0.255 |
#  Epoch 943 | Train loss: 0.255 |
#  Epoch 944 | Train loss: 0.255 |
#  Epoch 945 | Train loss: 0.255 |
#  Epoch 946 | Train loss: 0.255 |
#  Epoch 947 | Train loss: 0.255 |
#  Epoch 948 | Train loss: 0.255 |
#  Epoch 949 | Train loss: 0.255 |
#  Epoch 950 | Train loss: 0.255 |
#  Epoch 951 | Train loss: 0.255 |
#  Epoch 952 | Train loss: 0.255 |
#  Epoch 953 | Train loss: 0.255 |
#  Epoch 954 | Train loss: 0.255 |
#  Epoch 955 | Train loss: 0.255 |
#  Epoch 956 | Train loss: 0.255 |
#  Epoch 957 | Train loss: 0.255 |
#  Epoch 958 | Train loss: 0.255 |
#  Epoch 959 | Train loss: 0.255 |
#  Epoch 960 | Train loss: 0.255 |
#  Epoch 961 | Train loss: 0.255 |
#  Epoch 962 | Train loss: 0.255 |
#  Epoch 963 | Train loss: 0.255 |
#  Epoch 964 | Train loss: 0.255 |
#  Epoch 965 | Train loss: 0.255 |
#  Epoch 966 | Train loss: 0.255 |
#  Epoch 967 | Train loss: 0.255 |
#  Epoch 968 | Train loss: 0.255 |
#  Epoch 969 | Train loss: 0.255 |
#  Epoch 970 | Train loss: 0.255 |
#  Epoch 971 | Train loss: 0.255 |
#  Epoch 972 | Train loss: 0.255 |
#  Epoch 973 | Train loss: 0.255 |
#  Epoch 974 | Train loss: 0.255 |
#  Epoch 975 | Train loss: 0.255 |
#  Epoch 976 | Train loss: 0.255 |
#  Epoch 977 | Train loss: 0.255 |
#  Epoch 978 | Train loss: 0.255 |
#  Epoch 979 | Train loss: 0.255 |
#  Epoch 980 | Train loss: 0.255 |
#  Epoch 981 | Train loss: 0.255 |
#  Epoch 982 | Train loss: 0.255 |
#  Epoch 983 | Train loss: 0.255 |
#  Epoch 984 | Train loss: 0.255 |
#  Epoch 985 | Train loss: 0.255 |
#  Epoch 986 | Train loss: 0.255 |
#  Epoch 987 | Train loss: 0.255 |
#  Epoch 988 | Train loss: 0.255 |
#  Epoch 989 | Train loss: 0.255 |
#  Epoch 990 | Train loss: 0.255 |
#  Epoch 991 | Train loss: 0.255 |
#  Epoch 992 | Train loss: 0.255 |
#  Epoch 993 | Train loss: 0.255 |
#  Epoch 994 | Train loss: 0.255 |
#  Epoch 995 | Train loss: 0.255 |
#  Epoch 996 | Train loss: 0.255 |
#  Epoch 997 | Train loss: 0.255 |
#  Epoch 998 | Train loss: 0.255 |
#  Epoch 999 | Train loss: 0.255 |
#  Epoch 1000 | Train loss: 0.255 |
#  Epoch 1001 | Train loss: 0.255 |
#  Epoch 1002 | Train loss: 0.255 |
#  Epoch 1003 | Train loss: 0.255 |
#  Epoch 1004 | Train loss: 0.255 |
#  Epoch 1005 | Train loss: 0.255 |
#  Epoch 1006 | Train loss: 0.255 |
#  Epoch 1007 | Train loss: 0.255 |
#  Epoch 1008 | Train loss: 0.255 |
#  Epoch 1009 | Train loss: 0.255 |
#  Epoch 1010 | Train loss: 0.255 |
#  Epoch 1011 | Train loss: 0.255 |
#  Epoch 1012 | Train loss: 0.255 |
#  Epoch 1013 | Train loss: 0.255 |
#  Epoch 1014 | Train loss: 0.255 |
#  Epoch 1015 | Train loss: 0.255 |
#  Epoch 1016 | Train loss: 0.255 |
#  Epoch 1017 | Train loss: 0.255 |
#  Epoch 1018 | Train loss: 0.255 |
#  Epoch 1019 | Train loss: 0.255 |
#  Epoch 1020 | Train loss: 0.255 |
#  Epoch 1021 | Train loss: 0.255 |
#  Epoch 1022 | Train loss: 0.255 |
#  Epoch 1023 | Train loss: 0.255 |
#  Epoch 1024 | Train loss: 0.255 |
#  Epoch 1025 | Train loss: 0.255 |
#  Epoch 1026 | Train loss: 0.255 |
#  Epoch 1027 | Train loss: 0.255 |
#  Epoch 1028 | Train loss: 0.255 |
#  Epoch 1029 | Train loss: 0.255 |
#  Epoch 1030 | Train loss: 0.255 |
#  Epoch 1031 | Train loss: 0.255 |
#  Epoch 1032 | Train loss: 0.255 |
#  Epoch 1033 | Train loss: 0.255 |
#  Epoch 1034 | Train loss: 0.255 |
#  Epoch 1035 | Train loss: 0.255 |
#  Epoch 1036 | Train loss: 0.255 |
#  Epoch 1037 | Train loss: 0.255 |
#  Epoch 1038 | Train loss: 0.255 |
#  Epoch 1039 | Train loss: 0.255 |
#  Epoch 1040 | Train loss: 0.255 |
#  Epoch 1041 | Train loss: 0.255 |
#  Epoch 1042 | Train loss: 0.255 |
#  Epoch 1043 | Train loss: 0.255 |
#  Epoch 1044 | Train loss: 0.255 |
#  Epoch 1045 | Train loss: 0.255 |
#  Epoch 1046 | Train loss: 0.255 |
#  Epoch 1047 | Train loss: 0.255 |
#  Epoch 1048 | Train loss: 0.255 |
#  Epoch 1049 | Train loss: 0.255 |
#  Epoch 1050 | Train loss: 0.255 |
#  Epoch 1051 | Train loss: 0.255 |
#  Epoch 1052 | Train loss: 0.255 |
#  Epoch 1053 | Train loss: 0.255 |
#  Epoch 1054 | Train loss: 0.255 |
#  Epoch 1055 | Train loss: 0.255 |
#  Epoch 1056 | Train loss: 0.255 |
#  Epoch 1057 | Train loss: 0.255 |
#  Epoch 1058 | Train loss: 0.255 |
#  Epoch 1059 | Train loss: 0.255 |
#  Epoch 1060 | Train loss: 0.255 |
#  Epoch 1061 | Train loss: 0.255 |
#  Epoch 1062 | Train loss: 0.255 |
#  Epoch 1063 | Train loss: 0.255 |
#  Epoch 1064 | Train loss: 0.255 |
#  Epoch 1065 | Train loss: 0.255 |
#  Epoch 1066 | Train loss: 0.255 |
#  Epoch 1067 | Train loss: 0.255 |
#  Epoch 1068 | Train loss: 0.255 |
#  Epoch 1069 | Train loss: 0.255 |
#  Epoch 1070 | Train loss: 0.255 |
#  Epoch 1071 | Train loss: 0.255 |
#  Epoch 1072 | Train loss: 0.255 |
#  Epoch 1073 | Train loss: 0.255 |
#  Epoch 1074 | Train loss: 0.255 |
#  Epoch 1075 | Train loss: 0.255 |
#  Epoch 1076 | Train loss: 0.255 |
#  Epoch 1077 | Train loss: 0.255 |
#  Epoch 1078 | Train loss: 0.255 |
#  Epoch 1079 | Train loss: 0.255 |
#  Epoch 1080 | Train loss: 0.255 |
#  Epoch 1081 | Train loss: 0.255 |
#  Epoch 1082 | Train loss: 0.255 |
#  Epoch 1083 | Train loss: 0.255 |
#  Epoch 1084 | Train loss: 0.255 |
#  Epoch 1085 | Train loss: 0.255 |
#  Epoch 1086 | Train loss: 0.255 |
#  Epoch 1087 | Train loss: 0.255 |
#  Epoch 1088 | Train loss: 0.255 |
#  Epoch 1089 | Train loss: 0.255 |
#  Epoch 1090 | Train loss: 0.255 |
#  Epoch 1091 | Train loss: 0.255 |
#  Epoch 1092 | Train loss: 0.255 |
#  Epoch 1093 | Train loss: 0.255 |
#  Epoch 1094 | Train loss: 0.255 |
#  Epoch 1095 | Train loss: 0.255 |
#  Epoch 1096 | Train loss: 0.255 |
#  Epoch 1097 | Train loss: 0.255 |
#  Epoch 1098 | Train loss: 0.255 |
#  Epoch 1099 | Train loss: 0.255 |
#  Epoch 1100 | Train loss: 0.255 |
#  Epoch 1101 | Train loss: 0.255 |
#  Epoch 1102 | Train loss: 0.255 |
#  Epoch 1103 | Train loss: 0.255 |
#  Epoch 1104 | Train loss: 0.255 |
#  Epoch 1105 | Train loss: 0.255 |
#  Epoch 1106 | Train loss: 0.255 |
#  Epoch 1107 | Train loss: 0.255 |
#  Epoch 1108 | Train loss: 0.255 |
#  Epoch 1109 | Train loss: 0.255 |
#  Epoch 1110 | Train loss: 0.255 |
#  Epoch 1111 | Train loss: 0.255 |
#  Epoch 1112 | Train loss: 0.255 |
#  Epoch 1113 | Train loss: 0.255 |
#  Epoch 1114 | Train loss: 0.255 |
#  Epoch 1115 | Train loss: 0.255 |
#  Epoch 1116 | Train loss: 0.255 |
#  Epoch 1117 | Train loss: 0.255 |
#  Epoch 1118 | Train loss: 0.255 |
#  Epoch 1119 | Train loss: 0.255 |
#  Epoch 1120 | Train loss: 0.255 |
#  Epoch 1121 | Train loss: 0.255 |
#  Epoch 1122 | Train loss: 0.255 |
#  Epoch 1123 | Train loss: 0.255 |
#  Epoch 1124 | Train loss: 0.255 |
#  Epoch 1125 | Train loss: 0.255 |
#  Epoch 1126 | Train loss: 0.255 |
#  Epoch 1127 | Train loss: 0.255 |
#  Epoch 1128 | Train loss: 0.255 |
#  Epoch 1129 | Train loss: 0.255 |
#  Epoch 1130 | Train loss: 0.255 |
#  Epoch 1131 | Train loss: 0.255 |
#  Epoch 1132 | Train loss: 0.255 |
#  Epoch 1133 | Train loss: 0.255 |
#  Epoch 1134 | Train loss: 0.255 |
#  Epoch 1135 | Train loss: 0.255 |
#  Epoch 1136 | Train loss: 0.255 |
#  Epoch 1137 | Train loss: 0.255 |
#  Epoch 1138 | Train loss: 0.255 |
#  Epoch 1139 | Train loss: 0.255 |
#  Epoch 1140 | Train loss: 0.255 |
#  Epoch 1141 | Train loss: 0.255 |
#  Epoch 1142 | Train loss: 0.255 |
#  Epoch 1143 | Train loss: 0.255 |
#  Epoch 1144 | Train loss: 0.255 |
#  Epoch 1145 | Train loss: 0.255 |
#  Epoch 1146 | Train loss: 0.255 |
#  Epoch 1147 | Train loss: 0.255 |
#  Epoch 1148 | Train loss: 0.255 |
#  Epoch 1149 | Train loss: 0.255 |
#  Epoch 1150 | Train loss: 0.255 |
#  Epoch 1151 | Train loss: 0.255 |
#  Epoch 1152 | Train loss: 0.255 |
#  Epoch 1153 | Train loss: 0.255 |
#  Epoch 1154 | Train loss: 0.255 |
#  Epoch 1155 | Train loss: 0.255 |
#  Epoch 1156 | Train loss: 0.255 |
#  Epoch 1157 | Train loss: 0.255 |
#  Epoch 1158 | Train loss: 0.255 |
#  Epoch 1159 | Train loss: 0.255 |
#  Epoch 1160 | Train loss: 0.255 |
#  Epoch 1161 | Train loss: 0.255 |
#  Epoch 1162 | Train loss: 0.255 |
#  Epoch 1163 | Train loss: 0.255 |
#  Epoch 1164 | Train loss: 0.255 |
#  Epoch 1165 | Train loss: 0.255 |
#  Epoch 1166 | Train loss: 0.255 |
#  Epoch 1167 | Train loss: 0.255 |
#  Epoch 1168 | Train loss: 0.255 |
#  Epoch 1169 | Train loss: 0.255 |
#  Epoch 1170 | Train loss: 0.255 |
#  Epoch 1171 | Train loss: 0.255 |
#  Epoch 1172 | Train loss: 0.255 |
#  Epoch 1173 | Train loss: 0.255 |
#  Epoch 1174 | Train loss: 0.255 |
#  Epoch 1175 | Train loss: 0.255 |
#  Epoch 1176 | Train loss: 0.255 |
#  Epoch 1177 | Train loss: 0.255 |
#  Epoch 1178 | Train loss: 0.255 |
#  Epoch 1179 | Train loss: 0.255 |
#  Epoch 1180 | Train loss: 0.255 |
#  Epoch 1181 | Train loss: 0.255 |
#  Epoch 1182 | Train loss: 0.255 |
#  Epoch 1183 | Train loss: 0.255 |
#  Epoch 1184 | Train loss: 0.255 |
#  Epoch 1185 | Train loss: 0.255 |
#  Epoch 1186 | Train loss: 0.255 |
#  Epoch 1187 | Train loss: 0.255 |
#  Epoch 1188 | Train loss: 0.255 |
#  Epoch 1189 | Train loss: 0.255 |
#  Epoch 1190 | Train loss: 0.255 |
#  Epoch 1191 | Train loss: 0.255 |
#  Epoch 1192 | Train loss: 0.255 |
#  Epoch 1193 | Train loss: 0.255 |
#  Epoch 1194 | Train loss: 0.255 |
#  Epoch 1195 | Train loss: 0.255 |
#  Epoch 1196 | Train loss: 0.255 |
#  Epoch 1197 | Train loss: 0.255 |
#  Epoch 1198 | Train loss: 0.255 |
#  Epoch 1199 | Train loss: 0.255 |
#  Epoch 1200 | Train loss: 0.255 |
#  Epoch 1201 | Train loss: 0.255 |
#  Epoch 1202 | Train loss: 0.255 |
#  Epoch 1203 | Train loss: 0.255 |
#  Epoch 1204 | Train loss: 0.255 |
#  Epoch 1205 | Train loss: 0.255 |
#  Epoch 1206 | Train loss: 0.255 |
#  Epoch 1207 | Train loss: 0.255 |
#  Epoch 1208 | Train loss: 0.255 |
#  Epoch 1209 | Train loss: 0.255 |
#  Epoch 1210 | Train loss: 0.255 |
#  Epoch 1211 | Train loss: 0.255 |
#  Epoch 1212 | Train loss: 0.255 |
#  Epoch 1213 | Train loss: 0.255 |
#  Epoch 1214 | Train loss: 0.255 |
#  Epoch 1215 | Train loss: 0.255 |
#  Epoch 1216 | Train loss: 0.255 |
#  Epoch 1217 | Train loss: 0.255 |
#  Epoch 1218 | Train loss: 0.255 |
#  Epoch 1219 | Train loss: 0.255 |
#  Epoch 1220 | Train loss: 0.255 |
#  Epoch 1221 | Train loss: 0.255 |
#  Epoch 1222 | Train loss: 0.255 |
#  Epoch 1223 | Train loss: 0.255 |
#  Epoch 1224 | Train loss: 0.255 |
#  Epoch 1225 | Train loss: 0.255 |
#  Epoch 1226 | Train loss: 0.255 |
#  Epoch 1227 | Train loss: 0.255 |
#  Epoch 1228 | Train loss: 0.255 |
#  Epoch 1229 | Train loss: 0.255 |
#  Epoch 1230 | Train loss: 0.255 |
#  Epoch 1231 | Train loss: 0.255 |
#  Epoch 1232 | Train loss: 0.255 |
#  Epoch 1233 | Train loss: 0.255 |
#  Epoch 1234 | Train loss: 0.255 |
#  Epoch 1235 | Train loss: 0.255 |
#  Epoch 1236 | Train loss: 0.255 |
#  Epoch 1237 | Train loss: 0.255 |
#  Epoch 1238 | Train loss: 0.255 |
#  Epoch 1239 | Train loss: 0.255 |
#  Epoch 1240 | Train loss: 0.255 |
#  Epoch 1241 | Train loss: 0.255 |
#  Epoch 1242 | Train loss: 0.255 |
#  Epoch 1243 | Train loss: 0.255 |
#  Epoch 1244 | Train loss: 0.255 |
#  Epoch 1245 | Train loss: 0.255 |
#  Epoch 1246 | Train loss: 0.255 |
#  Epoch 1247 | Train loss: 0.255 |
#  Epoch 1248 | Train loss: 0.255 |
#  Epoch 1249 | Train loss: 0.255 |
#  Epoch 1250 | Train loss: 0.255 |
#  Epoch 1251 | Train loss: 0.255 |
#  Epoch 1252 | Train loss: 0.255 |
#  Epoch 1253 | Train loss: 0.255 |
#  Epoch 1254 | Train loss: 0.255 |
#  Epoch 1255 | Train loss: 0.255 |
#  Epoch 1256 | Train loss: 0.255 |
#  Epoch 1257 | Train loss: 0.255 |
#  Epoch 1258 | Train loss: 0.255 |
#  Epoch 1259 | Train loss: 0.255 |
#  Epoch 1260 | Train loss: 0.255 |
#  Epoch 1261 | Train loss: 0.255 |
#  Epoch 1262 | Train loss: 0.255 |
#  Epoch 1263 | Train loss: 0.255 |
#  Epoch 1264 | Train loss: 0.255 |
#  Epoch 1265 | Train loss: 0.255 |
#  Epoch 1266 | Train loss: 0.255 |
#  Epoch 1267 | Train loss: 0.255 |
#  Epoch 1268 | Train loss: 0.255 |
#  Epoch 1269 | Train loss: 0.255 |
#  Epoch 1270 | Train loss: 0.255 |
#  Epoch 1271 | Train loss: 0.255 |
#  Epoch 1272 | Train loss: 0.255 |
#  Epoch 1273 | Train loss: 0.255 |
#  Epoch 1274 | Train loss: 0.255 |
#  Epoch 1275 | Train loss: 0.255 |
#  Epoch 1276 | Train loss: 0.255 |
#  Epoch 1277 | Train loss: 0.255 |
#  Epoch 1278 | Train loss: 0.255 |
#  Epoch 1279 | Train loss: 0.255 |
#  Epoch 1280 | Train loss: 0.255 |
#  Epoch 1281 | Train loss: 0.255 |
#  Epoch 1282 | Train loss: 0.255 |
#  Epoch 1283 | Train loss: 0.255 |
#  Epoch 1284 | Train loss: 0.255 |
#  Epoch 1285 | Train loss: 0.255 |
#  Epoch 1286 | Train loss: 0.255 |
#  Epoch 1287 | Train loss: 0.255 |
#  Epoch 1288 | Train loss: 0.255 |
#  Epoch 1289 | Train loss: 0.255 |
#  Epoch 1290 | Train loss: 0.255 |
#  Epoch 1291 | Train loss: 0.255 |
#  Epoch 1292 | Train loss: 0.255 |
#  Epoch 1293 | Train loss: 0.255 |
#  Epoch 1294 | Train loss: 0.255 |
#  Epoch 1295 | Train loss: 0.255 |
#  Epoch 1296 | Train loss: 0.255 |
#  Epoch 1297 | Train loss: 0.255 |
#  Epoch 1298 | Train loss: 0.255 |
#  Epoch 1299 | Train loss: 0.255 |
#  Epoch 1300 | Train loss: 0.255 |
#  Epoch 1301 | Train loss: 0.255 |
#  Epoch 1302 | Train loss: 0.255 |
#  Epoch 1303 | Train loss: 0.255 |
#  Epoch 1304 | Train loss: 0.255 |
#  Epoch 1305 | Train loss: 0.255 |
#  Epoch 1306 | Train loss: 0.255 |
#  Epoch 1307 | Train loss: 0.255 |
#  Epoch 1308 | Train loss: 0.255 |
#  Epoch 1309 | Train loss: 0.255 |
#  Epoch 1310 | Train loss: 0.255 |
#  Epoch 1311 | Train loss: 0.255 |
#  Epoch 1312 | Train loss: 0.255 |
#  Epoch 1313 | Train loss: 0.255 |
#  Epoch 1314 | Train loss: 0.255 |
#  Epoch 1315 | Train loss: 0.255 |
#  Epoch 1316 | Train loss: 0.255 |
#  Epoch 1317 | Train loss: 0.255 |
#  Epoch 1318 | Train loss: 0.255 |
#  Epoch 1319 | Train loss: 0.255 |
#  Epoch 1320 | Train loss: 0.255 |
#  Epoch 1321 | Train loss: 0.255 |
#  Epoch 1322 | Train loss: 0.255 |
#  Epoch 1323 | Train loss: 0.255 |
#  Epoch 1324 | Train loss: 0.255 |
#  Epoch 1325 | Train loss: 0.255 |
#  Epoch 1326 | Train loss: 0.255 |
#  Epoch 1327 | Train loss: 0.255 |
#  Epoch 1328 | Train loss: 0.255 |
#  Epoch 1329 | Train loss: 0.255 |
#  Epoch 1330 | Train loss: 0.255 |
#  Epoch 1331 | Train loss: 0.255 |
#  Epoch 1332 | Train loss: 0.255 |
#  Epoch 1333 | Train loss: 0.255 |
#  Epoch 1334 | Train loss: 0.255 |
#  Epoch 1335 | Train loss: 0.255 |
#  Epoch 1336 | Train loss: 0.255 |
#  Epoch 1337 | Train loss: 0.255 |
#  Epoch 1338 | Train loss: 0.255 |
#  Epoch 1339 | Train loss: 0.255 |
#  Epoch 1340 | Train loss: 0.255 |
#  Epoch 1341 | Train loss: 0.255 |
#  Epoch 1342 | Train loss: 0.255 |
#  Epoch 1343 | Train loss: 0.255 |
#  Epoch 1344 | Train loss: 0.255 |
#  Epoch 1345 | Train loss: 0.255 |
#  Epoch 1346 | Train loss: 0.255 |
#  Epoch 1347 | Train loss: 0.255 |
#  Epoch 1348 | Train loss: 0.255 |
#  Epoch 1349 | Train loss: 0.255 |
#  Epoch 1350 | Train loss: 0.255 |
#  Epoch 1351 | Train loss: 0.255 |
#  Epoch 1352 | Train loss: 0.255 |
#  Epoch 1353 | Train loss: 0.254 |
#  Epoch 1354 | Train loss: 0.255 |
#  Epoch 1355 | Train loss: 0.254 |
#  Epoch 1356 | Train loss: 0.255 |
#  Epoch 1357 | Train loss: 0.255 |
#  Epoch 1358 | Train loss: 0.254 |
#  Epoch 1359 | Train loss: 0.254 |
#  Epoch 1360 | Train loss: 0.255 |
#  Epoch 1361 | Train loss: 0.255 |
#  Epoch 1362 | Train loss: 0.255 |
#  Epoch 1363 | Train loss: 0.255 |
#  Epoch 1364 | Train loss: 0.254 |
#  Epoch 1365 | Train loss: 0.255 |
#  Epoch 1366 | Train loss: 0.255 |
#  Epoch 1367 | Train loss: 0.255 |
#  Epoch 1368 | Train loss: 0.254 |
#  Epoch 1369 | Train loss: 0.254 |
#  Epoch 1370 | Train loss: 0.255 |
#  Epoch 1371 | Train loss: 0.255 |
#  Epoch 1372 | Train loss: 0.255 |
#  Epoch 1373 | Train loss: 0.255 |
#  Epoch 1374 | Train loss: 0.255 |
#  Epoch 1375 | Train loss: 0.254 |
#  Epoch 1376 | Train loss: 0.255 |
#  Epoch 1377 | Train loss: 0.255 |
#  Epoch 1378 | Train loss: 0.255 |
#  Epoch 1379 | Train loss: 0.254 |
#  Epoch 1380 | Train loss: 0.255 |
#  Epoch 1381 | Train loss: 0.255 |
#  Epoch 1382 | Train loss: 0.255 |
#  Epoch 1383 | Train loss: 0.254 |
#  Epoch 1384 | Train loss: 0.255 |
#  Epoch 1385 | Train loss: 0.255 |
#  Epoch 1386 | Train loss: 0.254 |
#  Epoch 1387 | Train loss: 0.255 |
#  Epoch 1388 | Train loss: 0.254 |
#  Epoch 1389 | Train loss: 0.254 |
#  Epoch 1390 | Train loss: 0.255 |
#  Epoch 1391 | Train loss: 0.255 |
#  Epoch 1392 | Train loss: 0.255 |
#  Epoch 1393 | Train loss: 0.255 |
#  Epoch 1394 | Train loss: 0.255 |
#  Epoch 1395 | Train loss: 0.254 |
#  Epoch 1396 | Train loss: 0.255 |
#  Epoch 1397 | Train loss: 0.254 |
#  Epoch 1398 | Train loss: 0.255 |
#  Epoch 1399 | Train loss: 0.255 |
#  Epoch 1400 | Train loss: 0.255 |
#  Epoch 1401 | Train loss: 0.255 |
#  Epoch 1402 | Train loss: 0.255 |
# ...
#  Epoch 9543 | Train loss: 0.001 |
#  Epoch 9544 | Train loss: 0.001 |
#  Epoch 9545 | Train loss: 0.001 |
#  Epoch 9546 | Train loss: 0.001 |
#  Epoch 9547 | Train loss: 0.001 |
#  Epoch 9548 | Train loss: 0.001 |
#  Epoch 9549 | Train loss: 0.001 |
#  Epoch 9550 | Train loss: 0.001 |
#  Epoch 9551 | Train loss: 0.001 |
#  Epoch 9552 | Train loss: 0.001 |
#  Epoch 9553 | Train loss: 0.001 |
#  Epoch 9554 | Train loss: 0.001 |
#  Epoch 9555 | Train loss: 0.001 |
#  Epoch 9556 | Train loss: 0.001 |
#  Epoch 9557 | Train loss: 0.001 |
#  Epoch 9558 | Train loss: 0.001 |
#  Epoch 9559 | Train loss: 0.001 |
#  Epoch 9560 | Train loss: 0.001 |
#  Epoch 9561 | Train loss: 0.001 |
#  Epoch 9562 | Train loss: 0.001 |
#  Epoch 9563 | Train loss: 0.001 |
#  Epoch 9564 | Train loss: 0.001 |
#  Epoch 9565 | Train loss: 0.001 |
#  Epoch 9566 | Train loss: 0.001 |
#  Epoch 9567 | Train loss: 0.001 |
#  Epoch 9568 | Train loss: 0.001 |
#  Epoch 9569 | Train loss: 0.001 |
#  Epoch 9570 | Train loss: 0.001 |
#  Epoch 9571 | Train loss: 0.001 |
#  Epoch 9572 | Train loss: 0.001 |
#  Epoch 9573 | Train loss: 0.001 |
#  Epoch 9574 | Train loss: 0.001 |
#  Epoch 9575 | Train loss: 0.001 |
#  Epoch 9576 | Train loss: 0.001 |
#  Epoch 9577 | Train loss: 0.001 |
#  Epoch 9578 | Train loss: 0.001 |
#  Epoch 9579 | Train loss: 0.001 |
#  Epoch 9580 | Train loss: 0.001 |
#  Epoch 9581 | Train loss: 0.001 |
#  Epoch 9582 | Train loss: 0.001 |
#  Epoch 9583 | Train loss: 0.001 |
#  Epoch 9584 | Train loss: 0.001 |
#  Epoch 9585 | Train loss: 0.001 |
#  Epoch 9586 | Train loss: 0.001 |
#  Epoch 9587 | Train loss: 0.001 |
#  Epoch 9588 | Train loss: 0.001 |
#  Epoch 9589 | Train loss: 0.001 |
#  Epoch 9590 | Train loss: 0.001 |
#  Epoch 9591 | Train loss: 0.001 |
#  Epoch 9592 | Train loss: 0.001 |
#  Epoch 9593 | Train loss: 0.001 |
#  Epoch 9594 | Train loss: 0.001 |
#  Epoch 9595 | Train loss: 0.001 |
#  Epoch 9596 | Train loss: 0.001 |
#  Epoch 9597 | Train loss: 0.001 |
#  Epoch 9598 | Train loss: 0.001 |
#  Epoch 9599 | Train loss: 0.001 |
#  Epoch 9600 | Train loss: 0.001 |
#  Epoch 9601 | Train loss: 0.001 |
#  Epoch 9602 | Train loss: 0.001 |
#  Epoch 9603 | Train loss: 0.001 |
#  Epoch 9604 | Train loss: 0.001 |
#  Epoch 9605 | Train loss: 0.001 |
#  Epoch 9606 | Train loss: 0.001 |
#  Epoch 9607 | Train loss: 0.001 |
#  Epoch 9608 | Train loss: 0.001 |
#  Epoch 9609 | Train loss: 0.001 |
#  Epoch 9610 | Train loss: 0.001 |
#  Epoch 9611 | Train loss: 0.001 |
#  Epoch 9612 | Train loss: 0.001 |
#  Epoch 9613 | Train loss: 0.001 |
#  Epoch 9614 | Train loss: 0.001 |
#  Epoch 9615 | Train loss: 0.001 |
#  Epoch 9616 | Train loss: 0.001 |
#  Epoch 9617 | Train loss: 0.001 |
#  Epoch 9618 | Train loss: 0.001 |
#  Epoch 9619 | Train loss: 0.001 |
#  Epoch 9620 | Train loss: 0.001 |
#  Epoch 9621 | Train loss: 0.001 |
#  Epoch 9622 | Train loss: 0.001 |
#  Epoch 9623 | Train loss: 0.001 |
#  Epoch 9624 | Train loss: 0.001 |
#  Epoch 9625 | Train loss: 0.001 |
#  Epoch 9626 | Train loss: 0.001 |
#  Epoch 9627 | Train loss: 0.001 |
#  Epoch 9628 | Train loss: 0.001 |
#  Epoch 9629 | Train loss: 0.001 |
#  Epoch 9630 | Train loss: 0.001 |
#  Epoch 9631 | Train loss: 0.001 |
#  Epoch 9632 | Train loss: 0.001 |
#  Epoch 9633 | Train loss: 0.001 |
#  Epoch 9634 | Train loss: 0.001 |
#  Epoch 9635 | Train loss: 0.001 |
#  Epoch 9636 | Train loss: 0.001 |
#  Epoch 9637 | Train loss: 0.001 |
#  Epoch 9638 | Train loss: 0.001 |
#  Epoch 9639 | Train loss: 0.001 |
#  Epoch 9640 | Train loss: 0.001 |
#  Epoch 9641 | Train loss: 0.001 |
#  Epoch 9642 | Train loss: 0.001 |
#  Epoch 9643 | Train loss: 0.001 |
#  Epoch 9644 | Train loss: 0.001 |
#  Epoch 9645 | Train loss: 0.001 |
#  Epoch 9646 | Train loss: 0.001 |
#  Epoch 9647 | Train loss: 0.001 |
#  Epoch 9648 | Train loss: 0.001 |
#  Epoch 9649 | Train loss: 0.001 |
#  Epoch 9650 | Train loss: 0.001 |
#  Epoch 9651 | Train loss: 0.001 |
#  Epoch 9652 | Train loss: 0.001 |
#  Epoch 9653 | Train loss: 0.001 |
#  Epoch 9654 | Train loss: 0.001 |
#  Epoch 9655 | Train loss: 0.001 |
#  Epoch 9656 | Train loss: 0.001 |
#  Epoch 9657 | Train loss: 0.001 |
#  Epoch 9658 | Train loss: 0.001 |
#  Epoch 9659 | Train loss: 0.001 |
#  Epoch 9660 | Train loss: 0.001 |
#  Epoch 9661 | Train loss: 0.001 |
#  Epoch 9662 | Train loss: 0.001 |
#  Epoch 9663 | Train loss: 0.001 |
#  Epoch 9664 | Train loss: 0.001 |
#  Epoch 9665 | Train loss: 0.001 |
#  Epoch 9666 | Train loss: 0.001 |
#  Epoch 9667 | Train loss: 0.001 |
#  Epoch 9668 | Train loss: 0.001 |
#  Epoch 9669 | Train loss: 0.001 |
#  Epoch 9670 | Train loss: 0.001 |
#  Epoch 9671 | Train loss: 0.001 |
#  Epoch 9672 | Train loss: 0.001 |
#  Epoch 9673 | Train loss: 0.001 |
#  Epoch 9674 | Train loss: 0.001 |
#  Epoch 9675 | Train loss: 0.001 |
#  Epoch 9676 | Train loss: 0.001 |
#  Epoch 9677 | Train loss: 0.001 |
#  Epoch 9678 | Train loss: 0.001 |
#  Epoch 9679 | Train loss: 0.001 |
#  Epoch 9680 | Train loss: 0.001 |
#  Epoch 9681 | Train loss: 0.001 |
#  Epoch 9682 | Train loss: 0.001 |
#  Epoch 9683 | Train loss: 0.001 |
#  Epoch 9684 | Train loss: 0.001 |
#  Epoch 9685 | Train loss: 0.001 |
#  Epoch 9686 | Train loss: 0.001 |
#  Epoch 9687 | Train loss: 0.001 |
#  Epoch 9688 | Train loss: 0.001 |
#  Epoch 9689 | Train loss: 0.001 |
#  Epoch 9690 | Train loss: 0.001 |
#  Epoch 9691 | Train loss: 0.001 |
#  Epoch 9692 | Train loss: 0.001 |
#  Epoch 9693 | Train loss: 0.001 |
#  Epoch 9694 | Train loss: 0.001 |
#  Epoch 9695 | Train loss: 0.001 |
#  Epoch 9696 | Train loss: 0.001 |
#  Epoch 9697 | Train loss: 0.001 |
#  Epoch 9698 | Train loss: 0.001 |
#  Epoch 9699 | Train loss: 0.001 |
#  Epoch 9700 | Train loss: 0.001 |
#  Epoch 9701 | Train loss: 0.001 |
#  Epoch 9702 | Train loss: 0.001 |
#  Epoch 9703 | Train loss: 0.001 |
#  Epoch 9704 | Train loss: 0.001 |
#  Epoch 9705 | Train loss: 0.001 |
#  Epoch 9706 | Train loss: 0.001 |
#  Epoch 9707 | Train loss: 0.001 |
#  Epoch 9708 | Train loss: 0.001 |
#  Epoch 9709 | Train loss: 0.001 |
#  Epoch 9710 | Train loss: 0.001 |
#  Epoch 9711 | Train loss: 0.001 |
#  Epoch 9712 | Train loss: 0.001 |
#  Epoch 9713 | Train loss: 0.001 |
#  Epoch 9714 | Train loss: 0.001 |
#  Epoch 9715 | Train loss: 0.001 |
#  Epoch 9716 | Train loss: 0.001 |
#  Epoch 9717 | Train loss: 0.001 |
#  Epoch 9718 | Train loss: 0.001 |
#  Epoch 9719 | Train loss: 0.001 |
#  Epoch 9720 | Train loss: 0.001 |
#  Epoch 9721 | Train loss: 0.001 |
#  Epoch 9722 | Train loss: 0.001 |
#  Epoch 9723 | Train loss: 0.001 |
#  Epoch 9724 | Train loss: 0.001 |
#  Epoch 9725 | Train loss: 0.001 |
#  Epoch 9726 | Train loss: 0.001 |
#  Epoch 9727 | Train loss: 0.001 |
#  Epoch 9728 | Train loss: 0.001 |
#  Epoch 9729 | Train loss: 0.001 |
#  Epoch 9730 | Train loss: 0.001 |
#  Epoch 9731 | Train loss: 0.001 |
#  Epoch 9732 | Train loss: 0.001 |
#  Epoch 9733 | Train loss: 0.001 |
#  Epoch 9734 | Train loss: 0.001 |
#  Epoch 9735 | Train loss: 0.001 |
#  Epoch 9736 | Train loss: 0.001 |
#  Epoch 9737 | Train loss: 0.001 |
#  Epoch 9738 | Train loss: 0.001 |
#  Epoch 9739 | Train loss: 0.001 |
#  Epoch 9740 | Train loss: 0.001 |
#  Epoch 9741 | Train loss: 0.001 |
#  Epoch 9742 | Train loss: 0.001 |
#  Epoch 9743 | Train loss: 0.001 |
#  Epoch 9744 | Train loss: 0.001 |
#  Epoch 9745 | Train loss: 0.001 |
#  Epoch 9746 | Train loss: 0.001 |
#  Epoch 9747 | Train loss: 0.001 |
#  Epoch 9748 | Train loss: 0.001 |
#  Epoch 9749 | Train loss: 0.001 |
#  Epoch 9750 | Train loss: 0.001 |
#  Epoch 9751 | Train loss: 0.001 |
#  Epoch 9752 | Train loss: 0.001 |
#  Epoch 9753 | Train loss: 0.001 |
#  Epoch 9754 | Train loss: 0.001 |
#  Epoch 9755 | Train loss: 0.001 |
#  Epoch 9756 | Train loss: 0.001 |
#  Epoch 9757 | Train loss: 0.001 |
#  Epoch 9758 | Train loss: 0.001 |
#  Epoch 9759 | Train loss: 0.001 |
#  Epoch 9760 | Train loss: 0.001 |
#  Epoch 9761 | Train loss: 0.001 |
#  Epoch 9762 | Train loss: 0.001 |
#  Epoch 9763 | Train loss: 0.001 |
#  Epoch 9764 | Train loss: 0.001 |
#  Epoch 9765 | Train loss: 0.001 |
#  Epoch 9766 | Train loss: 0.001 |
#  Epoch 9767 | Train loss: 0.001 |
#  Epoch 9768 | Train loss: 0.001 |
#  Epoch 9769 | Train loss: 0.001 |
#  Epoch 9770 | Train loss: 0.001 |
#  Epoch 9771 | Train loss: 0.001 |
#  Epoch 9772 | Train loss: 0.001 |
#  Epoch 9773 | Train loss: 0.001 |
#  Epoch 9774 | Train loss: 0.001 |
#  Epoch 9775 | Train loss: 0.001 |
#  Epoch 9776 | Train loss: 0.001 |
#  Epoch 9777 | Train loss: 0.001 |
#  Epoch 9778 | Train loss: 0.001 |
#  Epoch 9779 | Train loss: 0.001 |
#  Epoch 9780 | Train loss: 0.001 |
#  Epoch 9781 | Train loss: 0.001 |
#  Epoch 9782 | Train loss: 0.001 |
#  Epoch 9783 | Train loss: 0.001 |
#  Epoch 9784 | Train loss: 0.001 |
#  Epoch 9785 | Train loss: 0.001 |
#  Epoch 9786 | Train loss: 0.001 |
#  Epoch 9787 | Train loss: 0.001 |
#  Epoch 9788 | Train loss: 0.001 |
#  Epoch 9789 | Train loss: 0.001 |
#  Epoch 9790 | Train loss: 0.001 |
#  Epoch 9791 | Train loss: 0.001 |
#  Epoch 9792 | Train loss: 0.001 |
#  Epoch 9793 | Train loss: 0.001 |
#  Epoch 9794 | Train loss: 0.001 |
#  Epoch 9795 | Train loss: 0.001 |
#  Epoch 9796 | Train loss: 0.001 |
#  Epoch 9797 | Train loss: 0.001 |
#  Epoch 9798 | Train loss: 0.001 |
#  Epoch 9799 | Train loss: 0.001 |
#  Epoch 9800 | Train loss: 0.001 |
#  Epoch 9801 | Train loss: 0.001 |
#  Epoch 9802 | Train loss: 0.001 |
#  Epoch 9803 | Train loss: 0.001 |
#  Epoch 9804 | Train loss: 0.001 |
#  Epoch 9805 | Train loss: 0.001 |
#  Epoch 9806 | Train loss: 0.001 |
#  Epoch 9807 | Train loss: 0.001 |
#  Epoch 9808 | Train loss: 0.001 |
#  Epoch 9809 | Train loss: 0.001 |
#  Epoch 9810 | Train loss: 0.001 |
#  Epoch 9811 | Train loss: 0.001 |
#  Epoch 9812 | Train loss: 0.001 |
#  Epoch 9813 | Train loss: 0.001 |
#  Epoch 9814 | Train loss: 0.001 |
#  Epoch 9815 | Train loss: 0.001 |
#  Epoch 9816 | Train loss: 0.001 |
#  Epoch 9817 | Train loss: 0.001 |
#  Epoch 9818 | Train loss: 0.001 |
#  Epoch 9819 | Train loss: 0.001 |
#  Epoch 9820 | Train loss: 0.001 |
#  Epoch 9821 | Train loss: 0.001 |
#  Epoch 9822 | Train loss: 0.001 |
#  Epoch 9823 | Train loss: 0.001 |
#  Epoch 9824 | Train loss: 0.001 |
#  Epoch 9825 | Train loss: 0.001 |
#  Epoch 9826 | Train loss: 0.001 |
#  Epoch 9827 | Train loss: 0.001 |
#  Epoch 9828 | Train loss: 0.001 |
#  Epoch 9829 | Train loss: 0.001 |
#  Epoch 9830 | Train loss: 0.001 |
#  Epoch 9831 | Train loss: 0.001 |
#  Epoch 9832 | Train loss: 0.001 |
#  Epoch 9833 | Train loss: 0.001 |
#  Epoch 9834 | Train loss: 0.001 |
#  Epoch 9835 | Train loss: 0.001 |
#  Epoch 9836 | Train loss: 0.001 |
#  Epoch 9837 | Train loss: 0.001 |
#  Epoch 9838 | Train loss: 0.001 |
#  Epoch 9839 | Train loss: 0.001 |
#  Epoch 9840 | Train loss: 0.001 |
#  Epoch 9841 | Train loss: 0.001 |
#  Epoch 9842 | Train loss: 0.001 |
#  Epoch 9843 | Train loss: 0.001 |
#  Epoch 9844 | Train loss: 0.001 |
#  Epoch 9845 | Train loss: 0.001 |
#  Epoch 9846 | Train loss: 0.001 |
#  Epoch 9847 | Train loss: 0.001 |
#  Epoch 9848 | Train loss: 0.001 |
#  Epoch 9849 | Train loss: 0.001 |
#  Epoch 9850 | Train loss: 0.001 |
#  Epoch 9851 | Train loss: 0.001 |
#  Epoch 9852 | Train loss: 0.001 |
#  Epoch 9853 | Train loss: 0.001 |
#  Epoch 9854 | Train loss: 0.001 |
#  Epoch 9855 | Train loss: 0.001 |
#  Epoch 9856 | Train loss: 0.001 |
#  Epoch 9857 | Train loss: 0.001 |
#  Epoch 9858 | Train loss: 0.001 |
#  Epoch 9859 | Train loss: 0.001 |
#  Epoch 9860 | Train loss: 0.001 |
#  Epoch 9861 | Train loss: 0.001 |
#  Epoch 9862 | Train loss: 0.001 |
#  Epoch 9863 | Train loss: 0.001 |
#  Epoch 9864 | Train loss: 0.001 |
#  Epoch 9865 | Train loss: 0.001 |
#  Epoch 9866 | Train loss: 0.001 |
#  Epoch 9867 | Train loss: 0.001 |
#  Epoch 9868 | Train loss: 0.001 |
#  Epoch 9869 | Train loss: 0.001 |
#  Epoch 9870 | Train loss: 0.001 |
#  Epoch 9871 | Train loss: 0.001 |
#  Epoch 9872 | Train loss: 0.001 |
#  Epoch 9873 | Train loss: 0.001 |
#  Epoch 9874 | Train loss: 0.001 |
#  Epoch 9875 | Train loss: 0.001 |
#  Epoch 9876 | Train loss: 0.001 |
#  Epoch 9877 | Train loss: 0.001 |
#  Epoch 9878 | Train loss: 0.001 |
#  Epoch 9879 | Train loss: 0.001 |
#  Epoch 9880 | Train loss: 0.001 |
#  Epoch 9881 | Train loss: 0.001 |
#  Epoch 9882 | Train loss: 0.001 |
#  Epoch 9883 | Train loss: 0.001 |
#  Epoch 9884 | Train loss: 0.001 |
#  Epoch 9885 | Train loss: 0.001 |
#  Epoch 9886 | Train loss: 0.001 |
#  Epoch 9887 | Train loss: 0.001 |
#  Epoch 9888 | Train loss: 0.001 |
#  Epoch 9889 | Train loss: 0.001 |
#  Epoch 9890 | Train loss: 0.001 |
#  Epoch 9891 | Train loss: 0.001 |
#  Epoch 9892 | Train loss: 0.001 |
#  Epoch 9893 | Train loss: 0.001 |
#  Epoch 9894 | Train loss: 0.001 |
#  Epoch 9895 | Train loss: 0.001 |
#  Epoch 9896 | Train loss: 0.001 |
#  Epoch 9897 | Train loss: 0.001 |
#  Epoch 9898 | Train loss: 0.001 |
#  Epoch 9899 | Train loss: 0.001 |
#  Epoch 9900 | Train loss: 0.001 |
#  Epoch 9901 | Train loss: 0.001 |
#  Epoch 9902 | Train loss: 0.001 |
#  Epoch 9903 | Train loss: 0.001 |
#  Epoch 9904 | Train loss: 0.001 |
#  Epoch 9905 | Train loss: 0.001 |
#  Epoch 9906 | Train loss: 0.001 |
#  Epoch 9907 | Train loss: 0.001 |
#  Epoch 9908 | Train loss: 0.001 |
#  Epoch 9909 | Train loss: 0.001 |
#  Epoch 9910 | Train loss: 0.001 |
#  Epoch 9911 | Train loss: 0.001 |
#  Epoch 9912 | Train loss: 0.001 |
#  Epoch 9913 | Train loss: 0.001 |
#  Epoch 9914 | Train loss: 0.001 |
#  Epoch 9915 | Train loss: 0.001 |
#  Epoch 9916 | Train loss: 0.001 |
#  Epoch 9917 | Train loss: 0.001 |
#  Epoch 9918 | Train loss: 0.001 |
#  Epoch 9919 | Train loss: 0.001 |
#  Epoch 9920 | Train loss: 0.001 |
#  Epoch 9921 | Train loss: 0.001 |
#  Epoch 9922 | Train loss: 0.001 |
#  Epoch 9923 | Train loss: 0.001 |
#  Epoch 9924 | Train loss: 0.001 |
#  Epoch 9925 | Train loss: 0.001 |
#  Epoch 9926 | Train loss: 0.001 |
#  Epoch 9927 | Train loss: 0.001 |
#  Epoch 9928 | Train loss: 0.001 |
#  Epoch 9929 | Train loss: 0.001 |
#  Epoch 9930 | Train loss: 0.001 |
#  Epoch 9931 | Train loss: 0.001 |
#  Epoch 9932 | Train loss: 0.001 |
#  Epoch 9933 | Train loss: 0.001 |
#  Epoch 9934 | Train loss: 0.001 |
#  Epoch 9935 | Train loss: 0.001 |
#  Epoch 9936 | Train loss: 0.001 |
#  Epoch 9937 | Train loss: 0.001 |
#  Epoch 9938 | Train loss: 0.001 |
#  Epoch 9939 | Train loss: 0.001 |
#  Epoch 9940 | Train loss: 0.001 |
#  Epoch 9941 | Train loss: 0.001 |
#  Epoch 9942 | Train loss: 0.001 |
#  Epoch 9943 | Train loss: 0.001 |
#  Epoch 9944 | Train loss: 0.001 |
#  Epoch 9945 | Train loss: 0.001 |
#  Epoch 9946 | Train loss: 0.001 |
#  Epoch 9947 | Train loss: 0.001 |
#  Epoch 9948 | Train loss: 0.001 |
#  Epoch 9949 | Train loss: 0.001 |
#  Epoch 9950 | Train loss: 0.001 |
#  Epoch 9951 | Train loss: 0.001 |
#  Epoch 9952 | Train loss: 0.001 |
#  Epoch 9953 | Train loss: 0.001 |
#  Epoch 9954 | Train loss: 0.001 |
#  Epoch 9955 | Train loss: 0.001 |
#  Epoch 9956 | Train loss: 0.001 |
#  Epoch 9957 | Train loss: 0.001 |
#  Epoch 9958 | Train loss: 0.001 |
#  Epoch 9959 | Train loss: 0.001 |
#  Epoch 9960 | Train loss: 0.001 |
#  Epoch 9961 | Train loss: 0.001 |
#  Epoch 9962 | Train loss: 0.001 |
#  Epoch 9963 | Train loss: 0.001 |
#  Epoch 9964 | Train loss: 0.001 |
#  Epoch 9965 | Train loss: 0.001 |
#  Epoch 9966 | Train loss: 0.001 |
#  Epoch 9967 | Train loss: 0.001 |
#  Epoch 9968 | Train loss: 0.001 |
#  Epoch 9969 | Train loss: 0.001 |
#  Epoch 9970 | Train loss: 0.001 |
#  Epoch 9971 | Train loss: 0.001 |
#  Epoch 9972 | Train loss: 0.001 |
#  Epoch 9973 | Train loss: 0.001 |
#  Epoch 9974 | Train loss: 0.001 |
#  Epoch 9975 | Train loss: 0.001 |
#  Epoch 9976 | Train loss: 0.001 |
#  Epoch 9977 | Train loss: 0.001 |
#  Epoch 9978 | Train loss: 0.001 |
#  Epoch 9979 | Train loss: 0.001 |
#  Epoch 9980 | Train loss: 0.001 |
#  Epoch 9981 | Train loss: 0.001 |
#  Epoch 9982 | Train loss: 0.001 |
#  Epoch 9983 | Train loss: 0.001 |
#  Epoch 9984 | Train loss: 0.001 |
#  Epoch 9985 | Train loss: 0.001 |
#  Epoch 9986 | Train loss: 0.001 |
#  Epoch 9987 | Train loss: 0.001 |
#  Epoch 9988 | Train loss: 0.001 |
#  Epoch 9989 | Train loss: 0.001 |
#  Epoch 9990 | Train loss: 0.001 |
#  Epoch 9991 | Train loss: 0.001 |
#  Epoch 9992 | Train loss: 0.001 |
#  Epoch 9993 | Train loss: 0.001 |
#  Epoch 9994 | Train loss: 0.001 |
#  Epoch 9995 | Train loss: 0.001 |
#  Epoch 9996 | Train loss: 0.001 |
#  Epoch 9997 | Train loss: 0.001 |
#  Epoch 9998 | Train loss: 0.001 |
#  Epoch 9999 | Train loss: 0.001 |

# %%
x1_values = np.linspace(0, 1, 100) 
x2_values = np.linspace(0, 1, 100) 
grid_points = np.array([(x1, x2) for x1 in x1_values for x2 in x2_values])

inputs = torch.Tensor(grid_points)
predictions = nnet(inputs).detach().numpy()

# Graficar los resultados
plt.figure(figsize=(8, 6))
plt.scatter(grid_points[:, 0], grid_points[:, 1], c=predictions, cmap='coolwarm')
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('predicciones con PyTorch')
plt.colorbar()
plt.show()

# %%
plt.plot(train_loss_by_epoch)

### plot de la función de pérdida, ojo es una gráfica bastante pelada
