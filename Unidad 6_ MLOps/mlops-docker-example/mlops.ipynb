# %% [markdown]
# # build pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer

from sklearn.preprocessing import StandardScaler

import joblib

import pandas as pd

imputer_median = SimpleImputer(strategy='median')
imputer_mean = SimpleImputer(strategy='mean')
knn_imputer = KNNImputer()

scaler = StandardScaler()

lr = LinearRegression()

ct = ColumnTransformer([
    ("imputer_median", imputer_median, ['CRIM', 'ZN', 'NOX', 'DIS', 'PTRATIO','B']),
    ("imputer_mean", imputer_mean, ['RM', 'LSTAT']),
    ("knn_imputer", knn_imputer, ['INDUS', 'CHAS','AGE', 'RAD', 'TAX'])
])

pipe = Pipeline(steps=[
    ("fill_na", ct),
    ("scale", scaler),
    ("moodel", lr)
])


df_train = pd.read_csv('./files/train.csv')

X_train = df_train.drop(columns='MEDV')
y_train = df_train['MEDV']

pipe.fit(X_train, y_train)

pipe.score(X_train, y_train)
# Out:
# 0.6379836760633126

# %%
pipe
# Out:
# Pipeline(steps=[('fill_na',
#                  ColumnTransformer(transformers=[('imputer_median',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['CRIM', 'ZN', 'NOX', 'DIS',
#                                                    'PTRATIO', 'B']),
#                                                  ('imputer_mean',
#                                                   SimpleImputer(),
#                                                   ['RM', 'LSTAT']),
#                                                  ('knn_imputer', KNNImputer(),
#                                                   ['INDUS', 'CHAS', 'AGE',
#                                                    'RAD', 'TAX'])])),
#                 ('scale', StandardScaler()), ('moodel', LinearRegression())])

# %%
# save pipeline
joblib.dump(pipe, './docker/pipeline.pkl')
# Out:
# ['./docker/pipeline.pkl']

# %% [markdown]
# TP - Métricas - Regresión Lineal
#
# - R2 Train: 0.6379836760633126
# - RMSE Train: 5.810058588033976

# %% [markdown]
# # load pipeline

# %%
import joblib

pipeline = joblib.load('./docker/pipeline.pkl')

# %%
pipeline
# Out:
# Pipeline(steps=[('fill_na',
#                  ColumnTransformer(transformers=[('imputer_median',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['CRIM', 'ZN', 'NOX', 'DIS',
#                                                    'PTRATIO', 'B']),
#                                                  ('imputer_mean',
#                                                   SimpleImputer(),
#                                                   ['RM', 'LSTAT']),
#                                                  ('knn_imputer', KNNImputer(),
#                                                   ['INDUS', 'CHAS', 'AGE',
#                                                    'RAD', 'TAX'])])),
#                 ('scale', StandardScaler()), ('moodel', LinearRegression())])

# %%
import pandas as pd

df = pd.read_csv('./files/test.csv')
df.head(1)
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  0.35809  0.0    6.2   1.0  0.507  6.951  88.5  2.8617  8.0  307.0     17.4
#
#        B  LSTAT  MEDV
# 0  391.7   9.71  26.7

# %%
X = df.drop(columns='MEDV')
y = df['MEDV']

pipeline.score(X, y)
# Out:
# 0.5456894968938473

# %% [markdown]
# # docker

# %%
# build image
# !docker build -t inference-python-test ./docker
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 199B 0.0s done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/python:3.12-slim
# #2 DONE 0.7s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [internal] load build context
# #4 transferring context: 943B done
# #4 DONE 0.0s
#
# #5 [1/5] FROM docker.io/library/python:3.12-slim@sha256:fd95fa221297a88e1cf49c55ec1828edd7c5a428187e67b5d1805692d11588db
# #5 resolve docker.io/library/python:3.12-slim@sha256:fd95fa221297a88e1cf49c55ec1828edd7c5a428187e67b5d1805692d11588db 0.0s done
# #5 DONE 0.0s
#
# #6 [3/5] COPY requirements.txt ./
# #6 CACHED
#
# #7 [2/5] WORKDIR /app
# #7 CACHED
#
# #8 [4/5] RUN pip install --no-cache-dir -r requirements.txt
# #8 CACHED
#
# #9 [5/5] COPY . .
# #9 DONE 0.1s
#
# #10 exporting to image
# #10 exporting layers 0.1s done
# #10 exporting manifest sha256:9f07ad77a09f81fa8246752f36d2701827c8cd8d47f5b311ae185c3c2ad4a54d 0.0s done
# #10 exporting config sha256:d626289cf6f2efd974a67a61a6498022c9cdd7f49680980f1cd16f73222b5b81 0.0s done
# #10 exporting attestation manifest sha256:c5e42ff86e87ac05025ed262f0511a82c6c8cc79b208c6e16a8f06a4c57e1522 0.0s done
# #10 exporting manifest list sha256:bad69fe0d8500531937ab4bfd591eacf5eae3571b2305b85b8b56aa5e9daa18c 0.0s done
# #10 naming to docker.io/library/inference-python-test:latest done
# #10 unpacking to docker.io/library/inference-python-test:latest
# #10 unpacking to docker.io/library/inference-python-test:latest 3.6s done
# #10 DONE 3.8s

# %%
# run container
# !docker run -it --rm --name inference-python-test -v ./files:/files  inference-python-test
# Out:
# the input device is not a TTY.  If you are using mintty, try prefixing the command with 'winpty'

# %%
### en Windows es probable que sea necesario poner el path absoluto para montar el volumen
docker run -it --rm --name inference-python-test -v "C:\AA1\Unidad6_MLOps\mlops-docker-example\files:/files" inference-python-test

# %% [markdown]
# # check docker output

# %%
df_output = pd.read_csv('./files/output.csv')
df_output.head(1)
# Out:
#    MEDV_predicted
# 0       34.561835

# %%
from sklearn.metrics import r2_score, root_mean_squared_error

y_pred = df_output.MEDV_predicted

round(r2_score(y, y_pred),3), round(root_mean_squared_error(y, y_pred), 3)
# Out:
# (0.545, 5.805)

# %% [markdown]
# TP - Métricas - Regresión Lineal
#
# - R2 Test: 0.545
# - RMSE Test: 5.805
